# %% [markdown]
# 하나 쭉 시도하고 하나 쭉 시도하면 겹치지 않는 여러개가 만들어집니다.
# 현재는 한 번에 50개를 생성하도록 설정해두었습니다
# shift + enter를 이용해 하나하나 실행할 수 있습니다.

# %%
import random
import os
from datetime import datetime

# %% [markdown]
# #시작하기 전에 원고에 대체할 키워드가 몇 개 들어가있는지 확인하는 작업입니다.
#
# 새로운 원고를 생성하고 싶다면?
# 1) '원본' 폴더 안에 텍스트 파일을 생성하시고(왼쪽 바에 우클릭, 뉴파일 생성, '원하는 제목'.txt로 이름 변경)
# 2) 아래 with open('C:/Users/user/Desktop/원고치환/원본/법인회생.txt', 'r', encoding='utf-8') as file:
#     text = file.read()
# 이 부분에서 법인회생.txt 부분을 바꾸시면 됩니다.
# (ex. 지역주택조합.txt {내가입력했던것}.txt)

# %%
# 특정 단어와 대체어 리스트 정의
base_word = '지역주택조합 탈퇴 환불'

# 텍스트 파일 읽기
with open('C:/Users/user/Desktop/원고치환/원본/지역주택조합 탈퇴 환불.txt', 'r', encoding='utf-8') as file:
    input_file = file.read()

# 단어 개수 세기
count = input_file.count(base_word)

# 결과 출력
print(f"'{base_word}'는 텍스트 파일에 {count}번 등장합니다.")
# Out:
# '지역주택조합 탈퇴 환불'는 텍스트 파일에 4번 등장합니다.

# %% [markdown]
# #아래는 위에 입력한 '분양권해지'라는 단어를 무슨 단어로 바꿀 것인지를 정의했습니다.
# 각 리스트에서 하나씩 빼 와서 하나의 말뭉치를 만드는 과정입니다.
# 만약 지역에 '동탄'을 추가하고 싶으면, 리스트 첫번째 줄에 추가해주세요.
# 비슷한 느낌이 드는 단어들에 추가해주시면 됩니다.

# %%
import random

lists = [
    ['지역주택조합탈퇴', '지주택탈퇴', '협동조합형 민간임대주택'], #건물 종류
    ['단순변심으로', '시세하락으로 인해', '추후의 변심으로', '이중분양으로', '허위광고로', '공사지연으로', '마이너스피로'], #계약해지이유
    ['분양포기', '분양권취소', '단체소송', '전액환불', '반환청구 승소'], #원하는 것
    ['위약금없이', '추가분담금 늘어나기에', '중도금이자 마련', '잔금납부 불가능해'], #계약금
    ['법적 갈등', '승소 노하우', '고민된다면', '힘들다면', '출장상담'] #출장상담 or 빈칸
]

# 모든 가능한 문장들을 담을 리스트
requirement_words = []

# 모든 가능한 조합 생성
for _ in range(100):  # 예시로 100개 문장 생성
    # 첫 번째 리스트에서 요소 선택
    sentence_parts = []
    sentence_parts.append(random.choice(lists[0]))

    # 나머지 리스트에서 요소 선택
    for i in random.sample(range(1, 4), 3):  # 랜덤하게 4개 선택
        sentence_parts.append(random.choice(lists[i]))

    sentence_parts.append(random.choice(lists[4]))

    # 문장 생성 및 저장
    sentence = ' '.join(sentence_parts)
    requirement_words.append(sentence)

# 결과 확인
for idx, sentence in enumerate(requirement_words, start=1):
    print(f"{idx}. {sentence}")
# Out:
# 1. 지주택탈퇴 위약금없이 전액환불 단순변심으로 승소 노하우
# 2. 지역주택조합탈퇴 전액환불 마이너스피로 위약금없이 고민된다면
# 3. 지주택탈퇴 허위광고로 위약금없이 반환청구 승소 법적 갈등
# 4. 협동조합형 민간임대주택 시세하락으로 인해 추가분담금 늘어나기에 반환청구 승소 출장상담
# 5. 지역주택조합탈퇴 공사지연으로 분양권취소 추가분담금 늘어나기에 출장상담
# 6. 협동조합형 민간임대주택 시세하락으로 인해 분양권취소 잔금납부 불가능해 승소 노하우
# 7. 지주택탈퇴 추가분담금 늘어나기에 단체소송 시세하락으로 인해 승소 노하우
# 8. 지역주택조합탈퇴 중도금이자 마련 추후의 변심으로 전액환불 출장상담
# 9. 지주택탈퇴 시세하락으로 인해 잔금납부 불가능해 반환청구 승소 법적 갈등
# 10. 지주택탈퇴 잔금납부 불가능해 분양포기 허위광고로 승소 노하우
# 11. 지주택탈퇴 분양포기 추후의 변심으로 추가분담금 늘어나기에 고민된다면
# 12. 지주택탈퇴 위약금없이 추후의 변심으로 전액환불 고민된다면
# 13. 지역주택조합탈퇴 분양권취소 잔금납부 불가능해 허위광고로 출장상담
# 14. 지역주택조합탈퇴 위약금없이 분양권취소 이중분양으로 승소 노하우
# 15. 협동조합형 민간임대주택 허위광고로 반환청구 승소 추가분담금 늘어나기에 힘들다면
# 16. 협동조합형 민간임대주택 이중분양으로 중도금이자 마련 단체소송 고민된다면
# 17. 지역주택조합탈퇴 단순변심으로 단체소송 위약금없이 법적 갈등
# 18. 지역주택조합탈퇴 분양포기 잔금납부 불가능해 시세하락으로 인해 법적 갈등
# 19. 지역주택조합탈퇴 이중분양으로 분양포기 추가분담금 늘어나기에 승소 노하우
# 20. 협동조합형 민간임대주택 추후의 변심으로 단체소송 중도금이자 마련 법적 갈등
# 21. 지역주택조합탈퇴 잔금납부 불가능해 허위광고로 반환청구 승소 법적 갈등
# 22. 협동조합형 민간임대주택 단순변심으로 전액환불 위약금없이 고민된다면
# 23. 지역주택조합탈퇴 단순변심으로 중도금이자 마련 단체소송 법적 갈등
# 24. 협동조합형 민간임대주택 중도금이자 마련 마이너스피로 분양권취소 승소 노하우
# 25. 협동조합형 민간임대주택 전액환불 이중분양으로 잔금납부 불가능해 출장상담
# 26. 지역주택조합탈퇴 단순변심으로 반환청구 승소 잔금납부 불가능해 승소 노하우
# 27. 지역주택조합탈퇴 분양권취소 중도금이자 마련 공사지연으로 힘들다면
# 28. 지역주택조합탈퇴 전액환불 중도금이자 마련 추후의 변심으로 승소 노하우
# 29. 지역주택조합탈퇴 추가분담금 늘어나기에 반환청구 승소 마이너스피로 출장상담
# 30. 지역주택조합탈퇴 허위광고로 전액환불 위약금없이 승소 노하우
# 31. 지주택탈퇴 단체소송 위약금없이 추후의 변심으로 법적 갈등
# 32. 지역주택조합탈퇴 공사지연으로 추가분담금 늘어나기에 전액환불 승소 노하우
# 33. 지역주택조합탈퇴 위약금없이 전액환불 시세하락으로 인해 법적 갈등
# 34. 지주택탈퇴 반환청구 승소 중도금이자 마련 추후의 변심으로 출장상담
# 35. 협동조합형 민간임대주택 단순변심으로 단체소송 위약금없이 출장상담
# 36. 협동조합형 민간임대주택 분양포기 추가분담금 늘어나기에 공사지연으로 승소 노하우
# 37. 지주택탈퇴 허위광고로 전액환불 추가분담금 늘어나기에 법적 갈등
# 38. 지주택탈퇴 전액환불 추가분담금 늘어나기에 허위광고로 승소 노하우
# 39. 지역주택조합탈퇴 위약금없이 공사지연으로 단체소송 법적 갈등
# 40. 지주택탈퇴 잔금납부 불가능해 마이너스피로 분양권취소 승소 노하우
# 41. 지주택탈퇴 위약금없이 반환청구 승소 단순변심으로 출장상담
# 42. 지주택탈퇴 시세하락으로 인해 반환청구 승소 중도금이자 마련 고민된다면
# 43. 지역주택조합탈퇴 분양권취소 마이너스피로 잔금납부 불가능해 승소 노하우
# 44. 지주택탈퇴 전액환불 시세하락으로 인해 추가분담금 늘어나기에 승소 노하우
# 45. 지주택탈퇴 전액환불 추후의 변심으로 추가분담금 늘어나기에 승소 노하우
# 46. 지주택탈퇴 시세하락으로 인해 위약금없이 반환청구 승소 승소 노하우
# 47. 협동조합형 민간임대주택 분양포기 위약금없이 마이너스피로 고민된다면
# 48. 지주택탈퇴 단순변심으로 위약금없이 반환청구 승소 법적 갈등
# 49. 지역주택조합탈퇴 위약금없이 단순변심으로 반환청구 승소 힘들다면
# 50. 지주택탈퇴 잔금납부 불가능해 공사지연으로 반환청구 승소 법적 갈등
# 51. 지역주택조합탈퇴 분양포기 단순변심으로 중도금이자 마련 출장상담
# 52. 협동조합형 민간임대주택 시세하락으로 인해 잔금납부 불가능해 전액환불 승소 노하우
# 53. 협동조합형 민간임대주택 분양권취소 시세하락으로 인해 중도금이자 마련 힘들다면
# 54. 지역주택조합탈퇴 분양포기 위약금없이 이중분양으로 고민된다면
# 55. 지역주택조합탈퇴 추가분담금 늘어나기에 분양포기 공사지연으로 출장상담
# 56. 협동조합형 민간임대주택 공사지연으로 분양포기 잔금납부 불가능해 승소 노하우
# 57. 지주택탈퇴 중도금이자 마련 마이너스피로 반환청구 승소 힘들다면
# 58. 지역주택조합탈퇴 분양포기 마이너스피로 위약금없이 힘들다면
# 59. 지역주택조합탈퇴 이중분양으로 분양포기 중도금이자 마련 출장상담
# 60. 협동조합형 민간임대주택 이중분양으로 반환청구 승소 잔금납부 불가능해 승소 노하우
# 61. 협동조합형 민간임대주택 위약금없이 단체소송 공사지연으로 승소 노하우
# 62. 지주택탈퇴 전액환불 허위광고로 위약금없이 힘들다면
# 63. 지역주택조합탈퇴 반환청구 승소 위약금없이 이중분양으로 힘들다면
# 64. 지주택탈퇴 추후의 변심으로 추가분담금 늘어나기에 단체소송 힘들다면
# 65. 지주택탈퇴 전액환불 마이너스피로 중도금이자 마련 고민된다면
# 66. 지주택탈퇴 분양권취소 시세하락으로 인해 잔금납부 불가능해 힘들다면
# 67. 지역주택조합탈퇴 위약금없이 허위광고로 전액환불 법적 갈등
# 68. 지역주택조합탈퇴 추가분담금 늘어나기에 추후의 변심으로 분양권취소 고민된다면
# 69. 협동조합형 민간임대주택 공사지연으로 중도금이자 마련 단체소송 출장상담
# 70. 지역주택조합탈퇴 잔금납부 불가능해 전액환불 이중분양으로 승소 노하우
# 71. 지역주택조합탈퇴 분양포기 이중분양으로 잔금납부 불가능해 법적 갈등
# 72. 협동조합형 민간임대주택 공사지연으로 단체소송 추가분담금 늘어나기에 힘들다면
# 73. 협동조합형 민간임대주택 마이너스피로 추가분담금 늘어나기에 분양포기 법적 갈등
# 74. 협동조합형 민간임대주택 반환청구 승소 잔금납부 불가능해 시세하락으로 인해 법적 갈등
# 75. 지주택탈퇴 단순변심으로 분양포기 추가분담금 늘어나기에 법적 갈등
# 76. 협동조합형 민간임대주택 잔금납부 불가능해 분양포기 허위광고로 법적 갈등
# 77. 협동조합형 민간임대주택 단체소송 잔금납부 불가능해 공사지연으로 힘들다면
# 78. 지주택탈퇴 단체소송 중도금이자 마련 시세하락으로 인해 출장상담
# 79. 협동조합형 민간임대주택 전액환불 위약금없이 추후의 변심으로 출장상담
# 80. 협동조합형 민간임대주택 단순변심으로 단체소송 중도금이자 마련 승소 노하우
# 81. 협동조합형 민간임대주택 추가분담금 늘어나기에 전액환불 단순변심으로 법적 갈등
# 82. 지주택탈퇴 전액환불 허위광고로 위약금없이 힘들다면
# 83. 지역주택조합탈퇴 잔금납부 불가능해 단순변심으로 반환청구 승소 승소 노하우
# 84. 지역주택조합탈퇴 마이너스피로 잔금납부 불가능해 단체소송 출장상담
# 85. 지역주택조합탈퇴 전액환불 허위광고로 중도금이자 마련 법적 갈등
# 86. 지역주택조합탈퇴 전액환불 단순변심으로 추가분담금 늘어나기에 법적 갈등
# 87. 지역주택조합탈퇴 추후의 변심으로 잔금납부 불가능해 단체소송 출장상담
# 88. 협동조합형 민간임대주택 허위광고로 잔금납부 불가능해 단체소송 승소 노하우
# 89. 협동조합형 민간임대주택 추후의 변심으로 중도금이자 마련 전액환불 출장상담
# 90. 협동조합형 민간임대주택 반환청구 승소 중도금이자 마련 공사지연으로 힘들다면
# 91. 협동조합형 민간임대주택 위약금없이 시세하락으로 인해 분양권취소 고민된다면
# 92. 지역주택조합탈퇴 추가분담금 늘어나기에 추후의 변심으로 분양포기 힘들다면
# 93. 지역주택조합탈퇴 중도금이자 마련 추후의 변심으로 분양포기 힘들다면
# 94. 협동조합형 민간임대주택 허위광고로 추가분담금 늘어나기에 분양권취소 법적 갈등
# 95. 지역주택조합탈퇴 위약금없이 단순변심으로 전액환불 법적 갈등
# 96. 지역주택조합탈퇴 반환청구 승소 잔금납부 불가능해 공사지연으로 고민된다면
# 97. 협동조합형 민간임대주택 시세하락으로 인해 위약금없이 분양포기 힘들다면
# 98. 지주택탈퇴 단순변심으로 중도금이자 마련 반환청구 승소 승소 노하우
# 99. 지주택탈퇴 반환청구 승소 중도금이자 마련 마이너스피로 법적 갈등
# 100. 지역주택조합탈퇴 분양포기 추가분담금 늘어나기에 공사지연으로 힘들다면

# %% [markdown]
# 이렇게 제목들이 만들어졌습니다. 앞으로 '법인회생' 대신에 저것이 쓰일 것입니다.

# %%
requirement_words
# Out:
# ['지주택탈퇴 위약금없이 전액환불 단순변심으로 승소 노하우',
#  '지역주택조합탈퇴 전액환불 마이너스피로 위약금없이 고민된다면',
#  '지주택탈퇴 허위광고로 위약금없이 반환청구 승소 법적 갈등',
#  '협동조합형 민간임대주택 시세하락으로 인해 추가분담금 늘어나기에 반환청구 승소 출장상담',
#  '지역주택조합탈퇴 공사지연으로 분양권취소 추가분담금 늘어나기에 출장상담',
#  '협동조합형 민간임대주택 시세하락으로 인해 분양권취소 잔금납부 불가능해 승소 노하우',
#  '지주택탈퇴 추가분담금 늘어나기에 단체소송 시세하락으로 인해 승소 노하우',
#  '지역주택조합탈퇴 중도금이자 마련 추후의 변심으로 전액환불 출장상담',
#  '지주택탈퇴 시세하락으로 인해 잔금납부 불가능해 반환청구 승소 법적 갈등',
#  '지주택탈퇴 잔금납부 불가능해 분양포기 허위광고로 승소 노하우',
#  '지주택탈퇴 분양포기 추후의 변심으로 추가분담금 늘어나기에 고민된다면',
#  '지주택탈퇴 위약금없이 추후의 변심으로 전액환불 고민된다면',
#  '지역주택조합탈퇴 분양권취소 잔금납부 불가능해 허위광고로 출장상담',
#  '지역주택조합탈퇴 위약금없이 분양권취소 이중분양으로 승소 노하우',
#  '협동조합형 민간임대주택 허위광고로 반환청구 승소 추가분담금 늘어나기에 힘들다면',
#  '협동조합형 민간임대주택 이중분양으로 중도금이자 마련 단체소송 고민된다면',
#  '지역주택조합탈퇴 단순변심으로 단체소송 위약금없이 법적 갈등',
#  '지역주택조합탈퇴 분양포기 잔금납부 불가능해 시세하락으로 인해 법적 갈등',
#  '지역주택조합탈퇴 이중분양으로 분양포기 추가분담금 늘어나기에 승소 노하우',
#  '협동조합형 민간임대주택 추후의 변심으로 단체소송 중도금이자 마련 법적 갈등',
#  '지역주택조합탈퇴 잔금납부 불가능해 허위광고로 반환청구 승소 법적 갈등',
#  '협동조합형 민간임대주택 단순변심으로 전액환불 위약금없이 고민된다면',
#  '지역주택조합탈퇴 단순변심으로 중도금이자 마련 단체소송 법적 갈등',
#  '협동조합형 민간임대주택 중도금이자 마련 마이너스피로 분양권취소 승소 노하우',
#  '협동조합형 민간임대주택 전액환불 이중분양으로 잔금납부 불가능해 출장상담',
#  '지역주택조합탈퇴 단순변심으로 반환청구 승소 잔금납부 불가능해 승소 노하우',
#  '지역주택조합탈퇴 분양권취소 중도금이자 마련 공사지연으로 힘들다면',
#  '지역주택조합탈퇴 전액환불 중도금이자 마련 추후의 변심으로 승소 노하우',
#  '지역주택조합탈퇴 추가분담금 늘어나기에 반환청구 승소 마이너스피로 출장상담',
#  '지역주택조합탈퇴 허위광고로 전액환불 위약금없이 승소 노하우',
#  '지주택탈퇴 단체소송 위약금없이 추후의 변심으로 법적 갈등',
#  '지역주택조합탈퇴 공사지연으로 추가분담금 늘어나기에 전액환불 승소 노하우',
#  '지역주택조합탈퇴 위약금없이 전액환불 시세하락으로 인해 법적 갈등',
#  '지주택탈퇴 반환청구 승소 중도금이자 마련 추후의 변심으로 출장상담',
#  '협동조합형 민간임대주택 단순변심으로 단체소송 위약금없이 출장상담',
#  '협동조합형 민간임대주택 분양포기 추가분담금 늘어나기에 공사지연으로 승소 노하우',
#  '지주택탈퇴 허위광고로 전액환불 추가분담금 늘어나기에 법적 갈등',
#  '지주택탈퇴 전액환불 추가분담금 늘어나기에 허위광고로 승소 노하우',
#  '지역주택조합탈퇴 위약금없이 공사지연으로 단체소송 법적 갈등',
#  '지주택탈퇴 잔금납부 불가능해 마이너스피로 분양권취소 승소 노하우',
#  '지주택탈퇴 위약금없이 반환청구 승소 단순변심으로 출장상담',
#  '지주택탈퇴 시세하락으로 인해 반환청구 승소 중도금이자 마련 고민된다면',
#  '지역주택조합탈퇴 분양권취소 마이너스피로 잔금납부 불가능해 승소 노하우',
#  '지주택탈퇴 전액환불 시세하락으로 인해 추가분담금 늘어나기에 승소 노하우',
#  '지주택탈퇴 전액환불 추후의 변심으로 추가분담금 늘어나기에 승소 노하우',
#  '지주택탈퇴 시세하락으로 인해 위약금없이 반환청구 승소 승소 노하우',
#  '협동조합형 민간임대주택 분양포기 위약금없이 마이너스피로 고민된다면',
#  '지주택탈퇴 단순변심으로 위약금없이 반환청구 승소 법적 갈등',
#  '지역주택조합탈퇴 위약금없이 단순변심으로 반환청구 승소 힘들다면',
#  '지주택탈퇴 잔금납부 불가능해 공사지연으로 반환청구 승소 법적 갈등',
#  '지역주택조합탈퇴 분양포기 단순변심으로 중도금이자 마련 출장상담',
#  '협동조합형 민간임대주택 시세하락으로 인해 잔금납부 불가능해 전액환불 승소 노하우',
#  '협동조합형 민간임대주택 분양권취소 시세하락으로 인해 중도금이자 마련 힘들다면',
#  '지역주택조합탈퇴 분양포기 위약금없이 이중분양으로 고민된다면',
#  '지역주택조합탈퇴 추가분담금 늘어나기에 분양포기 공사지연으로 출장상담',
#  '협동조합형 민간임대주택 공사지연으로 분양포기 잔금납부 불가능해 승소 노하우',
#  '지주택탈퇴 중도금이자 마련 마이너스피로 반환청구 승소 힘들다면',
#  '지역주택조합탈퇴 분양포기 마이너스피로 위약금없이 힘들다면',
#  '지역주택조합탈퇴 이중분양으로 분양포기 중도금이자 마련 출장상담',
#  '협동조합형 민간임대주택 이중분양으로 반환청구 승소 잔금납부 불가능해 승소 노하우',
#  '협동조합형 민간임대주택 위약금없이 단체소송 공사지연으로 승소 노하우',
#  '지주택탈퇴 전액환불 허위광고로 위약금없이 힘들다면',
#  '지역주택조합탈퇴 반환청구 승소 위약금없이 이중분양으로 힘들다면',
#  '지주택탈퇴 추후의 변심으로 추가분담금 늘어나기에 단체소송 힘들다면',
#  '지주택탈퇴 전액환불 마이너스피로 중도금이자 마련 고민된다면',
#  '지주택탈퇴 분양권취소 시세하락으로 인해 잔금납부 불가능해 힘들다면',
#  '지역주택조합탈퇴 위약금없이 허위광고로 전액환불 법적 갈등',
#  '지역주택조합탈퇴 추가분담금 늘어나기에 추후의 변심으로 분양권취소 고민된다면',
#  '협동조합형 민간임대주택 공사지연으로 중도금이자 마련 단체소송 출장상담',
#  '지역주택조합탈퇴 잔금납부 불가능해 전액환불 이중분양으로 승소 노하우',
#  '지역주택조합탈퇴 분양포기 이중분양으로 잔금납부 불가능해 법적 갈등',
#  '협동조합형 민간임대주택 공사지연으로 단체소송 추가분담금 늘어나기에 힘들다면',
#  '협동조합형 민간임대주택 마이너스피로 추가분담금 늘어나기에 분양포기 법적 갈등',
#  '협동조합형 민간임대주택 반환청구 승소 잔금납부 불가능해 시세하락으로 인해 법적 갈등',
#  '지주택탈퇴 단순변심으로 분양포기 추가분담금 늘어나기에 법적 갈등',
#  '협동조합형 민간임대주택 잔금납부 불가능해 분양포기 허위광고로 법적 갈등',
#  '협동조합형 민간임대주택 단체소송 잔금납부 불가능해 공사지연으로 힘들다면',
#  '지주택탈퇴 단체소송 중도금이자 마련 시세하락으로 인해 출장상담',
#  '협동조합형 민간임대주택 전액환불 위약금없이 추후의 변심으로 출장상담',
#  '협동조합형 민간임대주택 단순변심으로 단체소송 중도금이자 마련 승소 노하우',
#  '협동조합형 민간임대주택 추가분담금 늘어나기에 전액환불 단순변심으로 법적 갈등',
#  '지주택탈퇴 전액환불 허위광고로 위약금없이 힘들다면',
#  '지역주택조합탈퇴 잔금납부 불가능해 단순변심으로 반환청구 승소 승소 노하우',
#  '지역주택조합탈퇴 마이너스피로 잔금납부 불가능해 단체소송 출장상담',
#  '지역주택조합탈퇴 전액환불 허위광고로 중도금이자 마련 법적 갈등',
#  '지역주택조합탈퇴 전액환불 단순변심으로 추가분담금 늘어나기에 법적 갈등',
#  '지역주택조합탈퇴 추후의 변심으로 잔금납부 불가능해 단체소송 출장상담',
#  '협동조합형 민간임대주택 허위광고로 잔금납부 불가능해 단체소송 승소 노하우',
#  '협동조합형 민간임대주택 추후의 변심으로 중도금이자 마련 전액환불 출장상담',
#  '협동조합형 민간임대주택 반환청구 승소 중도금이자 마련 공사지연으로 힘들다면',
#  '협동조합형 민간임대주택 위약금없이 시세하락으로 인해 분양권취소 고민된다면',
#  '지역주택조합탈퇴 추가분담금 늘어나기에 추후의 변심으로 분양포기 힘들다면',
#  '지역주택조합탈퇴 중도금이자 마련 추후의 변심으로 분양포기 힘들다면',
#  '협동조합형 민간임대주택 허위광고로 추가분담금 늘어나기에 분양권취소 법적 갈등',
#  '지역주택조합탈퇴 위약금없이 단순변심으로 전액환불 법적 갈등',
#  '지역주택조합탈퇴 반환청구 승소 잔금납부 불가능해 공사지연으로 고민된다면',
#  '협동조합형 민간임대주택 시세하락으로 인해 위약금없이 분양포기 힘들다면',
#  '지주택탈퇴 단순변심으로 중도금이자 마련 반환청구 승소 승소 노하우',
#  '지주택탈퇴 반환청구 승소 중도금이자 마련 마이너스피로 법적 갈등',
#  '지역주택조합탈퇴 분양포기 추가분담금 늘어나기에 공사지연으로 힘들다면']

# %% [markdown]
# 확인해보니 잘 나왔습니다.

# %% [markdown]
# 아래는 원래 하던 것처럼, A씨를 E씨로 바꾸고... 유사도를 낮추려 바꿀 단어 리스트를 이용해
# 실제로 단어를 바꾸는 과정입니다.
# 여기에는 'synonym.txt'라는 파일(좌측 바에 있음)을 사용하므로, 수정하고 싶으면 거기서 수정해주세요.
# 저장하고 돌리는 것은 필수

# %%
current_date = datetime.now().strftime("%Y%m%d_%H%M")

# %%
import random
import os
import shutil
from datetime import datetime

# 전역 변수로 output_folder 선언
output_folder = ""

# 대체어 딕셔너리를 읽어오는 함수
def read_synonyms(filename):
    synonyms_dict = {}
    with open(filename, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.split(':')
            if len(parts) == 2:
                word = parts[0].strip().strip("'")
                synonyms = parts[1].strip().strip('[]\n').replace("'", "").split(', ')
                synonyms_dict[word] = synonyms
    return synonyms_dict

# 입력 텍스트 파일 처리 함수
def replace_words_with_synonyms(text, synonyms_dict):
    for word, synonyms in synonyms_dict.items():
        if word in text:
            text = text.replace(word, random.choice(synonyms))
    return text

# 추가된 단어 치환 및 파일 생성 함수
def replace_and_generate_files(input_file, base_word, requirement_words, synonyms_dict):
    global output_folder  # 전역 변수로 선언
    
    # 현재 날짜와 시간을 포맷에 맞게 생성
    current_date = datetime.now().strftime("%Y%m%d_%H%M")
    
    # 결과를 저장할 폴더 생성
    output_folder = os.path.join(base_word, current_date)
    os.makedirs(output_folder, exist_ok=True)
    
    # 각 requirement_word 별로 파일 생성
    for i, replacement in enumerate(requirement_words):
        modified_text = input_file.replace(base_word, replacement)
        modified_text = replace_words_with_synonyms(modified_text, synonyms_dict)
        
        # 파일명에 순서 번호를 붙여 겹치지 않게 만듦
        output_filename = os.path.join(output_folder, f"{i + 1}_{replacement}.txt")
        with open(output_filename, 'w', encoding='utf-8') as file:
            file.write(modified_text)
        print(f"{output_filename} 파일이 생성되었습니다.")

# 함수 정의: 원고 파일을 각 수신자에게 배분하는 함수
def distribute_files_to_recipients(input_folder, recipients, base_word, current_date):
    # 배분 기본 폴더
    base_folder = f'{base_word} 배분'

    # 각 수신자 폴더 경로 생성
    for recipient in recipients:
        recipient_folder = os.path.join(base_folder, current_date, recipient)
        os.makedirs(recipient_folder, exist_ok=True)

    file_list = sorted(os.listdir(input_folder))

    num_recipients = len(recipients)
    files_per_recipient = len(file_list) // num_recipients

    for i, file_name in enumerate(file_list):
        if file_name.endswith('.txt'):
            src = os.path.join(input_folder, file_name)
            recipient_index = i % num_recipients
            recipient = recipients[recipient_index]
            dst = os.path.join(base_folder, current_date, recipient, file_name)
            shutil.copy(src, dst)
            print(f"{file_name} 파일이 {recipient} 폴더에 복사되었습니다.")

# 대체어 딕셔너리 읽기
synonyms_dict = read_synonyms('synonym.txt')

recipients = ['이사님', '팀장님', '주휘']

# 파일 생성 함수 호출
replace_and_generate_files(input_file, base_word, requirement_words, synonyms_dict)

# 생성된 파일 목록 출력
if output_folder:
    print(f"\n폴더 '{output_folder}'의 내용:")
    for filename in os.listdir(output_folder):
        print(filename)

# 파일 배분 함수 호출
input_folder = rf'C:\Users\user\Desktop\원고치환\{output_folder}'
distribute_files_to_recipients(input_folder, recipients, base_word, datetime.now().strftime("%Y%m%d_%H%M"))

print("\n모든 파일 생성 및 배분이 완료되었습니다.")
# Out:
# 지역주택조합 탈퇴 환불\20240719_1419\1_지주택탈퇴 위약금없이 전액환불 단순변심으로 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\2_지역주택조합탈퇴 전액환불 마이너스피로 위약금없이 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\3_지주택탈퇴 허위광고로 위약금없이 반환청구 승소 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\4_협동조합형 민간임대주택 시세하락으로 인해 추가분담금 늘어나기에 반환청구 승소 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\5_지역주택조합탈퇴 공사지연으로 분양권취소 추가분담금 늘어나기에 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\6_협동조합형 민간임대주택 시세하락으로 인해 분양권취소 잔금납부 불가능해 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\7_지주택탈퇴 추가분담금 늘어나기에 단체소송 시세하락으로 인해 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\8_지역주택조합탈퇴 중도금이자 마련 추후의 변심으로 전액환불 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\9_지주택탈퇴 시세하락으로 인해 잔금납부 불가능해 반환청구 승소 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\10_지주택탈퇴 잔금납부 불가능해 분양포기 허위광고로 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\11_지주택탈퇴 분양포기 추후의 변심으로 추가분담금 늘어나기에 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\12_지주택탈퇴 위약금없이 추후의 변심으로 전액환불 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\13_지역주택조합탈퇴 분양권취소 잔금납부 불가능해 허위광고로 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\14_지역주택조합탈퇴 위약금없이 분양권취소 이중분양으로 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\15_협동조합형 민간임대주택 허위광고로 반환청구 승소 추가분담금 늘어나기에 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\16_협동조합형 민간임대주택 이중분양으로 중도금이자 마련 단체소송 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\17_지역주택조합탈퇴 단순변심으로 단체소송 위약금없이 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\18_지역주택조합탈퇴 분양포기 잔금납부 불가능해 시세하락으로 인해 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\19_지역주택조합탈퇴 이중분양으로 분양포기 추가분담금 늘어나기에 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\20_협동조합형 민간임대주택 추후의 변심으로 단체소송 중도금이자 마련 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\21_지역주택조합탈퇴 잔금납부 불가능해 허위광고로 반환청구 승소 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\22_협동조합형 민간임대주택 단순변심으로 전액환불 위약금없이 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\23_지역주택조합탈퇴 단순변심으로 중도금이자 마련 단체소송 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\24_협동조합형 민간임대주택 중도금이자 마련 마이너스피로 분양권취소 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\25_협동조합형 민간임대주택 전액환불 이중분양으로 잔금납부 불가능해 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\26_지역주택조합탈퇴 단순변심으로 반환청구 승소 잔금납부 불가능해 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\27_지역주택조합탈퇴 분양권취소 중도금이자 마련 공사지연으로 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\28_지역주택조합탈퇴 전액환불 중도금이자 마련 추후의 변심으로 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\29_지역주택조합탈퇴 추가분담금 늘어나기에 반환청구 승소 마이너스피로 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\30_지역주택조합탈퇴 허위광고로 전액환불 위약금없이 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\31_지주택탈퇴 단체소송 위약금없이 추후의 변심으로 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\32_지역주택조합탈퇴 공사지연으로 추가분담금 늘어나기에 전액환불 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\33_지역주택조합탈퇴 위약금없이 전액환불 시세하락으로 인해 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\34_지주택탈퇴 반환청구 승소 중도금이자 마련 추후의 변심으로 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\35_협동조합형 민간임대주택 단순변심으로 단체소송 위약금없이 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\36_협동조합형 민간임대주택 분양포기 추가분담금 늘어나기에 공사지연으로 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\37_지주택탈퇴 허위광고로 전액환불 추가분담금 늘어나기에 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\38_지주택탈퇴 전액환불 추가분담금 늘어나기에 허위광고로 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\39_지역주택조합탈퇴 위약금없이 공사지연으로 단체소송 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\40_지주택탈퇴 잔금납부 불가능해 마이너스피로 분양권취소 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\41_지주택탈퇴 위약금없이 반환청구 승소 단순변심으로 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\42_지주택탈퇴 시세하락으로 인해 반환청구 승소 중도금이자 마련 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\43_지역주택조합탈퇴 분양권취소 마이너스피로 잔금납부 불가능해 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\44_지주택탈퇴 전액환불 시세하락으로 인해 추가분담금 늘어나기에 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\45_지주택탈퇴 전액환불 추후의 변심으로 추가분담금 늘어나기에 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\46_지주택탈퇴 시세하락으로 인해 위약금없이 반환청구 승소 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\47_협동조합형 민간임대주택 분양포기 위약금없이 마이너스피로 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\48_지주택탈퇴 단순변심으로 위약금없이 반환청구 승소 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\49_지역주택조합탈퇴 위약금없이 단순변심으로 반환청구 승소 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\50_지주택탈퇴 잔금납부 불가능해 공사지연으로 반환청구 승소 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\51_지역주택조합탈퇴 분양포기 단순변심으로 중도금이자 마련 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\52_협동조합형 민간임대주택 시세하락으로 인해 잔금납부 불가능해 전액환불 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\53_협동조합형 민간임대주택 분양권취소 시세하락으로 인해 중도금이자 마련 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\54_지역주택조합탈퇴 분양포기 위약금없이 이중분양으로 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\55_지역주택조합탈퇴 추가분담금 늘어나기에 분양포기 공사지연으로 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\56_협동조합형 민간임대주택 공사지연으로 분양포기 잔금납부 불가능해 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\57_지주택탈퇴 중도금이자 마련 마이너스피로 반환청구 승소 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\58_지역주택조합탈퇴 분양포기 마이너스피로 위약금없이 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\59_지역주택조합탈퇴 이중분양으로 분양포기 중도금이자 마련 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\60_협동조합형 민간임대주택 이중분양으로 반환청구 승소 잔금납부 불가능해 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\61_협동조합형 민간임대주택 위약금없이 단체소송 공사지연으로 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\62_지주택탈퇴 전액환불 허위광고로 위약금없이 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\63_지역주택조합탈퇴 반환청구 승소 위약금없이 이중분양으로 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\64_지주택탈퇴 추후의 변심으로 추가분담금 늘어나기에 단체소송 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\65_지주택탈퇴 전액환불 마이너스피로 중도금이자 마련 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\66_지주택탈퇴 분양권취소 시세하락으로 인해 잔금납부 불가능해 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\67_지역주택조합탈퇴 위약금없이 허위광고로 전액환불 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\68_지역주택조합탈퇴 추가분담금 늘어나기에 추후의 변심으로 분양권취소 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\69_협동조합형 민간임대주택 공사지연으로 중도금이자 마련 단체소송 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\70_지역주택조합탈퇴 잔금납부 불가능해 전액환불 이중분양으로 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\71_지역주택조합탈퇴 분양포기 이중분양으로 잔금납부 불가능해 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\72_협동조합형 민간임대주택 공사지연으로 단체소송 추가분담금 늘어나기에 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\73_협동조합형 민간임대주택 마이너스피로 추가분담금 늘어나기에 분양포기 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\74_협동조합형 민간임대주택 반환청구 승소 잔금납부 불가능해 시세하락으로 인해 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\75_지주택탈퇴 단순변심으로 분양포기 추가분담금 늘어나기에 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\76_협동조합형 민간임대주택 잔금납부 불가능해 분양포기 허위광고로 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\77_협동조합형 민간임대주택 단체소송 잔금납부 불가능해 공사지연으로 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\78_지주택탈퇴 단체소송 중도금이자 마련 시세하락으로 인해 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\79_협동조합형 민간임대주택 전액환불 위약금없이 추후의 변심으로 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\80_협동조합형 민간임대주택 단순변심으로 단체소송 중도금이자 마련 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\81_협동조합형 민간임대주택 추가분담금 늘어나기에 전액환불 단순변심으로 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\82_지주택탈퇴 전액환불 허위광고로 위약금없이 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\83_지역주택조합탈퇴 잔금납부 불가능해 단순변심으로 반환청구 승소 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\84_지역주택조합탈퇴 마이너스피로 잔금납부 불가능해 단체소송 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\85_지역주택조합탈퇴 전액환불 허위광고로 중도금이자 마련 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\86_지역주택조합탈퇴 전액환불 단순변심으로 추가분담금 늘어나기에 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\87_지역주택조합탈퇴 추후의 변심으로 잔금납부 불가능해 단체소송 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\88_협동조합형 민간임대주택 허위광고로 잔금납부 불가능해 단체소송 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\89_협동조합형 민간임대주택 추후의 변심으로 중도금이자 마련 전액환불 출장상담.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\90_협동조합형 민간임대주택 반환청구 승소 중도금이자 마련 공사지연으로 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\91_협동조합형 민간임대주택 위약금없이 시세하락으로 인해 분양권취소 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\92_지역주택조합탈퇴 추가분담금 늘어나기에 추후의 변심으로 분양포기 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\93_지역주택조합탈퇴 중도금이자 마련 추후의 변심으로 분양포기 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\94_협동조합형 민간임대주택 허위광고로 추가분담금 늘어나기에 분양권취소 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\95_지역주택조합탈퇴 위약금없이 단순변심으로 전액환불 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\96_지역주택조합탈퇴 반환청구 승소 잔금납부 불가능해 공사지연으로 고민된다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\97_협동조합형 민간임대주택 시세하락으로 인해 위약금없이 분양포기 힘들다면.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\98_지주택탈퇴 단순변심으로 중도금이자 마련 반환청구 승소 승소 노하우.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\99_지주택탈퇴 반환청구 승소 중도금이자 마련 마이너스피로 법적 갈등.txt 파일이 생성되었습니다.
# 지역주택조합 탈퇴 환불\20240719_1419\100_지역주택조합탈퇴 분양포기 추가분담금 늘어나기에 공사지연으로 힘들다면.txt 파일이 생성되었습니다.
#
# 폴더 '지역주택조합 탈퇴 환불\20240719_1419'의 내용:
# 100_지역주택조합탈퇴 분양포기 추가분담금 늘어나기에 공사지연으로 힘들다면.txt
# 10_지주택탈퇴 잔금납부 불가능해 분양포기 허위광고로 승소 노하우.txt
# 11_지주택탈퇴 분양포기 추후의 변심으로 추가분담금 늘어나기에 고민된다면.txt
# 12_지주택탈퇴 위약금없이 추후의 변심으로 전액환불 고민된다면.txt
# 13_지역주택조합탈퇴 분양권취소 잔금납부 불가능해 허위광고로 출장상담.txt
# 14_지역주택조합탈퇴 위약금없이 분양권취소 이중분양으로 승소 노하우.txt
# 15_협동조합형 민간임대주택 허위광고로 반환청구 승소 추가분담금 늘어나기에 힘들다면.txt
# 16_협동조합형 민간임대주택 이중분양으로 중도금이자 마련 단체소송 고민된다면.txt
# 17_지역주택조합탈퇴 단순변심으로 단체소송 위약금없이 법적 갈등.txt
# 18_지역주택조합탈퇴 분양포기 잔금납부 불가능해 시세하락으로 인해 법적 갈등.txt
# 19_지역주택조합탈퇴 이중분양으로 분양포기 추가분담금 늘어나기에 승소 노하우.txt
# 1_지주택탈퇴 위약금없이 전액환불 단순변심으로 승소 노하우.txt
# 20_협동조합형 민간임대주택 추후의 변심으로 단체소송 중도금이자 마련 법적 갈등.txt
# 21_지역주택조합탈퇴 잔금납부 불가능해 허위광고로 반환청구 승소 법적 갈등.txt
# 22_협동조합형 민간임대주택 단순변심으로 전액환불 위약금없이 고민된다면.txt
# 23_지역주택조합탈퇴 단순변심으로 중도금이자 마련 단체소송 법적 갈등.txt
# 24_협동조합형 민간임대주택 중도금이자 마련 마이너스피로 분양권취소 승소 노하우.txt
# 25_협동조합형 민간임대주택 전액환불 이중분양으로 잔금납부 불가능해 출장상담.txt
# 26_지역주택조합탈퇴 단순변심으로 반환청구 승소 잔금납부 불가능해 승소 노하우.txt
# 27_지역주택조합탈퇴 분양권취소 중도금이자 마련 공사지연으로 힘들다면.txt
# 28_지역주택조합탈퇴 전액환불 중도금이자 마련 추후의 변심으로 승소 노하우.txt
# 29_지역주택조합탈퇴 추가분담금 늘어나기에 반환청구 승소 마이너스피로 출장상담.txt
# 2_지역주택조합탈퇴 전액환불 마이너스피로 위약금없이 고민된다면.txt
# 30_지역주택조합탈퇴 허위광고로 전액환불 위약금없이 승소 노하우.txt
# 31_지주택탈퇴 단체소송 위약금없이 추후의 변심으로 법적 갈등.txt
# 32_지역주택조합탈퇴 공사지연으로 추가분담금 늘어나기에 전액환불 승소 노하우.txt
# 33_지역주택조합탈퇴 위약금없이 전액환불 시세하락으로 인해 법적 갈등.txt
# 34_지주택탈퇴 반환청구 승소 중도금이자 마련 추후의 변심으로 출장상담.txt
# 35_협동조합형 민간임대주택 단순변심으로 단체소송 위약금없이 출장상담.txt
# 36_협동조합형 민간임대주택 분양포기 추가분담금 늘어나기에 공사지연으로 승소 노하우.txt
# 37_지주택탈퇴 허위광고로 전액환불 추가분담금 늘어나기에 법적 갈등.txt
# 38_지주택탈퇴 전액환불 추가분담금 늘어나기에 허위광고로 승소 노하우.txt
# 39_지역주택조합탈퇴 위약금없이 공사지연으로 단체소송 법적 갈등.txt
# 3_지주택탈퇴 허위광고로 위약금없이 반환청구 승소 법적 갈등.txt
# 40_지주택탈퇴 잔금납부 불가능해 마이너스피로 분양권취소 승소 노하우.txt
# 41_지주택탈퇴 위약금없이 반환청구 승소 단순변심으로 출장상담.txt
# 42_지주택탈퇴 시세하락으로 인해 반환청구 승소 중도금이자 마련 고민된다면.txt
# 43_지역주택조합탈퇴 분양권취소 마이너스피로 잔금납부 불가능해 승소 노하우.txt
# 44_지주택탈퇴 전액환불 시세하락으로 인해 추가분담금 늘어나기에 승소 노하우.txt
# 45_지주택탈퇴 전액환불 추후의 변심으로 추가분담금 늘어나기에 승소 노하우.txt
# 46_지주택탈퇴 시세하락으로 인해 위약금없이 반환청구 승소 승소 노하우.txt
# 47_협동조합형 민간임대주택 분양포기 위약금없이 마이너스피로 고민된다면.txt
# 48_지주택탈퇴 단순변심으로 위약금없이 반환청구 승소 법적 갈등.txt
# 49_지역주택조합탈퇴 위약금없이 단순변심으로 반환청구 승소 힘들다면.txt
# 4_협동조합형 민간임대주택 시세하락으로 인해 추가분담금 늘어나기에 반환청구 승소 출장상담.txt
# 50_지주택탈퇴 잔금납부 불가능해 공사지연으로 반환청구 승소 법적 갈등.txt
# 51_지역주택조합탈퇴 분양포기 단순변심으로 중도금이자 마련 출장상담.txt
# 52_협동조합형 민간임대주택 시세하락으로 인해 잔금납부 불가능해 전액환불 승소 노하우.txt
# 53_협동조합형 민간임대주택 분양권취소 시세하락으로 인해 중도금이자 마련 힘들다면.txt
# 54_지역주택조합탈퇴 분양포기 위약금없이 이중분양으로 고민된다면.txt
# 55_지역주택조합탈퇴 추가분담금 늘어나기에 분양포기 공사지연으로 출장상담.txt
# 56_협동조합형 민간임대주택 공사지연으로 분양포기 잔금납부 불가능해 승소 노하우.txt
# 57_지주택탈퇴 중도금이자 마련 마이너스피로 반환청구 승소 힘들다면.txt
# 58_지역주택조합탈퇴 분양포기 마이너스피로 위약금없이 힘들다면.txt
# 59_지역주택조합탈퇴 이중분양으로 분양포기 중도금이자 마련 출장상담.txt
# 5_지역주택조합탈퇴 공사지연으로 분양권취소 추가분담금 늘어나기에 출장상담.txt
# 60_협동조합형 민간임대주택 이중분양으로 반환청구 승소 잔금납부 불가능해 승소 노하우.txt
# 61_협동조합형 민간임대주택 위약금없이 단체소송 공사지연으로 승소 노하우.txt
# 62_지주택탈퇴 전액환불 허위광고로 위약금없이 힘들다면.txt
# 63_지역주택조합탈퇴 반환청구 승소 위약금없이 이중분양으로 힘들다면.txt
# 64_지주택탈퇴 추후의 변심으로 추가분담금 늘어나기에 단체소송 힘들다면.txt
# 65_지주택탈퇴 전액환불 마이너스피로 중도금이자 마련 고민된다면.txt
# 66_지주택탈퇴 분양권취소 시세하락으로 인해 잔금납부 불가능해 힘들다면.txt
# 67_지역주택조합탈퇴 위약금없이 허위광고로 전액환불 법적 갈등.txt
# 68_지역주택조합탈퇴 추가분담금 늘어나기에 추후의 변심으로 분양권취소 고민된다면.txt
# 69_협동조합형 민간임대주택 공사지연으로 중도금이자 마련 단체소송 출장상담.txt
# 6_협동조합형 민간임대주택 시세하락으로 인해 분양권취소 잔금납부 불가능해 승소 노하우.txt
# 70_지역주택조합탈퇴 잔금납부 불가능해 전액환불 이중분양으로 승소 노하우.txt
# 71_지역주택조합탈퇴 분양포기 이중분양으로 잔금납부 불가능해 법적 갈등.txt
# 72_협동조합형 민간임대주택 공사지연으로 단체소송 추가분담금 늘어나기에 힘들다면.txt
# 73_협동조합형 민간임대주택 마이너스피로 추가분담금 늘어나기에 분양포기 법적 갈등.txt
# 74_협동조합형 민간임대주택 반환청구 승소 잔금납부 불가능해 시세하락으로 인해 법적 갈등.txt
# 75_지주택탈퇴 단순변심으로 분양포기 추가분담금 늘어나기에 법적 갈등.txt
# 76_협동조합형 민간임대주택 잔금납부 불가능해 분양포기 허위광고로 법적 갈등.txt
# 77_협동조합형 민간임대주택 단체소송 잔금납부 불가능해 공사지연으로 힘들다면.txt
# 78_지주택탈퇴 단체소송 중도금이자 마련 시세하락으로 인해 출장상담.txt
# 79_협동조합형 민간임대주택 전액환불 위약금없이 추후의 변심으로 출장상담.txt
# 7_지주택탈퇴 추가분담금 늘어나기에 단체소송 시세하락으로 인해 승소 노하우.txt
# 80_협동조합형 민간임대주택 단순변심으로 단체소송 중도금이자 마련 승소 노하우.txt
# 81_협동조합형 민간임대주택 추가분담금 늘어나기에 전액환불 단순변심으로 법적 갈등.txt
# 82_지주택탈퇴 전액환불 허위광고로 위약금없이 힘들다면.txt
# 83_지역주택조합탈퇴 잔금납부 불가능해 단순변심으로 반환청구 승소 승소 노하우.txt
# 84_지역주택조합탈퇴 마이너스피로 잔금납부 불가능해 단체소송 출장상담.txt
# 85_지역주택조합탈퇴 전액환불 허위광고로 중도금이자 마련 법적 갈등.txt
# 86_지역주택조합탈퇴 전액환불 단순변심으로 추가분담금 늘어나기에 법적 갈등.txt
# 87_지역주택조합탈퇴 추후의 변심으로 잔금납부 불가능해 단체소송 출장상담.txt
# 88_협동조합형 민간임대주택 허위광고로 잔금납부 불가능해 단체소송 승소 노하우.txt
# 89_협동조합형 민간임대주택 추후의 변심으로 중도금이자 마련 전액환불 출장상담.txt
# 8_지역주택조합탈퇴 중도금이자 마련 추후의 변심으로 전액환불 출장상담.txt
# 90_협동조합형 민간임대주택 반환청구 승소 중도금이자 마련 공사지연으로 힘들다면.txt
# 91_협동조합형 민간임대주택 위약금없이 시세하락으로 인해 분양권취소 고민된다면.txt
# 92_지역주택조합탈퇴 추가분담금 늘어나기에 추후의 변심으로 분양포기 힘들다면.txt
# 93_지역주택조합탈퇴 중도금이자 마련 추후의 변심으로 분양포기 힘들다면.txt
# 94_협동조합형 민간임대주택 허위광고로 추가분담금 늘어나기에 분양권취소 법적 갈등.txt
# 95_지역주택조합탈퇴 위약금없이 단순변심으로 전액환불 법적 갈등.txt
# 96_지역주택조합탈퇴 반환청구 승소 잔금납부 불가능해 공사지연으로 고민된다면.txt
# 97_협동조합형 민간임대주택 시세하락으로 인해 위약금없이 분양포기 힘들다면.txt
# 98_지주택탈퇴 단순변심으로 중도금이자 마련 반환청구 승소 승소 노하우.txt
# 99_지주택탈퇴 반환청구 승소 중도금이자 마련 마이너스피로 법적 갈등.txt
# 9_지주택탈퇴 시세하락으로 인해 잔금납부 불가능해 반환청구 승소 법적 갈등.txt
# 100_지역주택조합탈퇴 분양포기 추가분담금 늘어나기에 공사지연으로 힘들다면.txt 파일이 이사님 폴더에 복사되었습니다.
# 10_지주택탈퇴 잔금납부 불가능해 분양포기 허위광고로 승소 노하우.txt 파일이 팀장님 폴더에 복사되었습니다.
# 11_지주택탈퇴 분양포기 추후의 변심으로 추가분담금 늘어나기에 고민된다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 12_지주택탈퇴 위약금없이 추후의 변심으로 전액환불 고민된다면.txt 파일이 이사님 폴더에 복사되었습니다.
# 13_지역주택조합탈퇴 분양권취소 잔금납부 불가능해 허위광고로 출장상담.txt 파일이 팀장님 폴더에 복사되었습니다.
# 14_지역주택조합탈퇴 위약금없이 분양권취소 이중분양으로 승소 노하우.txt 파일이 주휘 폴더에 복사되었습니다.
# 15_협동조합형 민간임대주택 허위광고로 반환청구 승소 추가분담금 늘어나기에 힘들다면.txt 파일이 이사님 폴더에 복사되었습니다.
# 16_협동조합형 민간임대주택 이중분양으로 중도금이자 마련 단체소송 고민된다면.txt 파일이 팀장님 폴더에 복사되었습니다.
# 17_지역주택조합탈퇴 단순변심으로 단체소송 위약금없이 법적 갈등.txt 파일이 주휘 폴더에 복사되었습니다.
# 18_지역주택조합탈퇴 분양포기 잔금납부 불가능해 시세하락으로 인해 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 19_지역주택조합탈퇴 이중분양으로 분양포기 추가분담금 늘어나기에 승소 노하우.txt 파일이 팀장님 폴더에 복사되었습니다.
# 1_지주택탈퇴 위약금없이 전액환불 단순변심으로 승소 노하우.txt 파일이 주휘 폴더에 복사되었습니다.
# 20_협동조합형 민간임대주택 추후의 변심으로 단체소송 중도금이자 마련 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 21_지역주택조합탈퇴 잔금납부 불가능해 허위광고로 반환청구 승소 법적 갈등.txt 파일이 팀장님 폴더에 복사되었습니다.
# 22_협동조합형 민간임대주택 단순변심으로 전액환불 위약금없이 고민된다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 23_지역주택조합탈퇴 단순변심으로 중도금이자 마련 단체소송 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 24_협동조합형 민간임대주택 중도금이자 마련 마이너스피로 분양권취소 승소 노하우.txt 파일이 팀장님 폴더에 복사되었습니다.
# 25_협동조합형 민간임대주택 전액환불 이중분양으로 잔금납부 불가능해 출장상담.txt 파일이 주휘 폴더에 복사되었습니다.
# 26_지역주택조합탈퇴 단순변심으로 반환청구 승소 잔금납부 불가능해 승소 노하우.txt 파일이 이사님 폴더에 복사되었습니다.
# 27_지역주택조합탈퇴 분양권취소 중도금이자 마련 공사지연으로 힘들다면.txt 파일이 팀장님 폴더에 복사되었습니다.
# 28_지역주택조합탈퇴 전액환불 중도금이자 마련 추후의 변심으로 승소 노하우.txt 파일이 주휘 폴더에 복사되었습니다.
# 29_지역주택조합탈퇴 추가분담금 늘어나기에 반환청구 승소 마이너스피로 출장상담.txt 파일이 이사님 폴더에 복사되었습니다.
# 2_지역주택조합탈퇴 전액환불 마이너스피로 위약금없이 고민된다면.txt 파일이 팀장님 폴더에 복사되었습니다.
# 30_지역주택조합탈퇴 허위광고로 전액환불 위약금없이 승소 노하우.txt 파일이 주휘 폴더에 복사되었습니다.
# 31_지주택탈퇴 단체소송 위약금없이 추후의 변심으로 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 32_지역주택조합탈퇴 공사지연으로 추가분담금 늘어나기에 전액환불 승소 노하우.txt 파일이 팀장님 폴더에 복사되었습니다.
# 33_지역주택조합탈퇴 위약금없이 전액환불 시세하락으로 인해 법적 갈등.txt 파일이 주휘 폴더에 복사되었습니다.
# 34_지주택탈퇴 반환청구 승소 중도금이자 마련 추후의 변심으로 출장상담.txt 파일이 이사님 폴더에 복사되었습니다.
# 35_협동조합형 민간임대주택 단순변심으로 단체소송 위약금없이 출장상담.txt 파일이 팀장님 폴더에 복사되었습니다.
# 36_협동조합형 민간임대주택 분양포기 추가분담금 늘어나기에 공사지연으로 승소 노하우.txt 파일이 주휘 폴더에 복사되었습니다.
# 37_지주택탈퇴 허위광고로 전액환불 추가분담금 늘어나기에 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 38_지주택탈퇴 전액환불 추가분담금 늘어나기에 허위광고로 승소 노하우.txt 파일이 팀장님 폴더에 복사되었습니다.
# 39_지역주택조합탈퇴 위약금없이 공사지연으로 단체소송 법적 갈등.txt 파일이 주휘 폴더에 복사되었습니다.
# 3_지주택탈퇴 허위광고로 위약금없이 반환청구 승소 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 40_지주택탈퇴 잔금납부 불가능해 마이너스피로 분양권취소 승소 노하우.txt 파일이 팀장님 폴더에 복사되었습니다.
# 41_지주택탈퇴 위약금없이 반환청구 승소 단순변심으로 출장상담.txt 파일이 주휘 폴더에 복사되었습니다.
# 42_지주택탈퇴 시세하락으로 인해 반환청구 승소 중도금이자 마련 고민된다면.txt 파일이 이사님 폴더에 복사되었습니다.
# 43_지역주택조합탈퇴 분양권취소 마이너스피로 잔금납부 불가능해 승소 노하우.txt 파일이 팀장님 폴더에 복사되었습니다.
# 44_지주택탈퇴 전액환불 시세하락으로 인해 추가분담금 늘어나기에 승소 노하우.txt 파일이 주휘 폴더에 복사되었습니다.
# 45_지주택탈퇴 전액환불 추후의 변심으로 추가분담금 늘어나기에 승소 노하우.txt 파일이 이사님 폴더에 복사되었습니다.
# 46_지주택탈퇴 시세하락으로 인해 위약금없이 반환청구 승소 승소 노하우.txt 파일이 팀장님 폴더에 복사되었습니다.
# 47_협동조합형 민간임대주택 분양포기 위약금없이 마이너스피로 고민된다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 48_지주택탈퇴 단순변심으로 위약금없이 반환청구 승소 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 49_지역주택조합탈퇴 위약금없이 단순변심으로 반환청구 승소 힘들다면.txt 파일이 팀장님 폴더에 복사되었습니다.
# 4_협동조합형 민간임대주택 시세하락으로 인해 추가분담금 늘어나기에 반환청구 승소 출장상담.txt 파일이 주휘 폴더에 복사되었습니다.
# 50_지주택탈퇴 잔금납부 불가능해 공사지연으로 반환청구 승소 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 51_지역주택조합탈퇴 분양포기 단순변심으로 중도금이자 마련 출장상담.txt 파일이 팀장님 폴더에 복사되었습니다.
# 52_협동조합형 민간임대주택 시세하락으로 인해 잔금납부 불가능해 전액환불 승소 노하우.txt 파일이 주휘 폴더에 복사되었습니다.
# 53_협동조합형 민간임대주택 분양권취소 시세하락으로 인해 중도금이자 마련 힘들다면.txt 파일이 이사님 폴더에 복사되었습니다.
# 54_지역주택조합탈퇴 분양포기 위약금없이 이중분양으로 고민된다면.txt 파일이 팀장님 폴더에 복사되었습니다.
# 55_지역주택조합탈퇴 추가분담금 늘어나기에 분양포기 공사지연으로 출장상담.txt 파일이 주휘 폴더에 복사되었습니다.
# 56_협동조합형 민간임대주택 공사지연으로 분양포기 잔금납부 불가능해 승소 노하우.txt 파일이 이사님 폴더에 복사되었습니다.
# 57_지주택탈퇴 중도금이자 마련 마이너스피로 반환청구 승소 힘들다면.txt 파일이 팀장님 폴더에 복사되었습니다.
# 58_지역주택조합탈퇴 분양포기 마이너스피로 위약금없이 힘들다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 59_지역주택조합탈퇴 이중분양으로 분양포기 중도금이자 마련 출장상담.txt 파일이 이사님 폴더에 복사되었습니다.
# 5_지역주택조합탈퇴 공사지연으로 분양권취소 추가분담금 늘어나기에 출장상담.txt 파일이 팀장님 폴더에 복사되었습니다.
# 60_협동조합형 민간임대주택 이중분양으로 반환청구 승소 잔금납부 불가능해 승소 노하우.txt 파일이 주휘 폴더에 복사되었습니다.
# 61_협동조합형 민간임대주택 위약금없이 단체소송 공사지연으로 승소 노하우.txt 파일이 이사님 폴더에 복사되었습니다.
# 62_지주택탈퇴 전액환불 허위광고로 위약금없이 힘들다면.txt 파일이 팀장님 폴더에 복사되었습니다.
# 63_지역주택조합탈퇴 반환청구 승소 위약금없이 이중분양으로 힘들다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 64_지주택탈퇴 추후의 변심으로 추가분담금 늘어나기에 단체소송 힘들다면.txt 파일이 이사님 폴더에 복사되었습니다.
# 65_지주택탈퇴 전액환불 마이너스피로 중도금이자 마련 고민된다면.txt 파일이 팀장님 폴더에 복사되었습니다.
# 66_지주택탈퇴 분양권취소 시세하락으로 인해 잔금납부 불가능해 힘들다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 67_지역주택조합탈퇴 위약금없이 허위광고로 전액환불 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 68_지역주택조합탈퇴 추가분담금 늘어나기에 추후의 변심으로 분양권취소 고민된다면.txt 파일이 팀장님 폴더에 복사되었습니다.
# 69_협동조합형 민간임대주택 공사지연으로 중도금이자 마련 단체소송 출장상담.txt 파일이 주휘 폴더에 복사되었습니다.
# 6_협동조합형 민간임대주택 시세하락으로 인해 분양권취소 잔금납부 불가능해 승소 노하우.txt 파일이 이사님 폴더에 복사되었습니다.
# 70_지역주택조합탈퇴 잔금납부 불가능해 전액환불 이중분양으로 승소 노하우.txt 파일이 팀장님 폴더에 복사되었습니다.
# 71_지역주택조합탈퇴 분양포기 이중분양으로 잔금납부 불가능해 법적 갈등.txt 파일이 주휘 폴더에 복사되었습니다.
# 72_협동조합형 민간임대주택 공사지연으로 단체소송 추가분담금 늘어나기에 힘들다면.txt 파일이 이사님 폴더에 복사되었습니다.
# 73_협동조합형 민간임대주택 마이너스피로 추가분담금 늘어나기에 분양포기 법적 갈등.txt 파일이 팀장님 폴더에 복사되었습니다.
# 74_협동조합형 민간임대주택 반환청구 승소 잔금납부 불가능해 시세하락으로 인해 법적 갈등.txt 파일이 주휘 폴더에 복사되었습니다.
# 75_지주택탈퇴 단순변심으로 분양포기 추가분담금 늘어나기에 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 76_협동조합형 민간임대주택 잔금납부 불가능해 분양포기 허위광고로 법적 갈등.txt 파일이 팀장님 폴더에 복사되었습니다.
# 77_협동조합형 민간임대주택 단체소송 잔금납부 불가능해 공사지연으로 힘들다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 78_지주택탈퇴 단체소송 중도금이자 마련 시세하락으로 인해 출장상담.txt 파일이 이사님 폴더에 복사되었습니다.
# 79_협동조합형 민간임대주택 전액환불 위약금없이 추후의 변심으로 출장상담.txt 파일이 팀장님 폴더에 복사되었습니다.
# 7_지주택탈퇴 추가분담금 늘어나기에 단체소송 시세하락으로 인해 승소 노하우.txt 파일이 주휘 폴더에 복사되었습니다.
# 80_협동조합형 민간임대주택 단순변심으로 단체소송 중도금이자 마련 승소 노하우.txt 파일이 이사님 폴더에 복사되었습니다.
# 81_협동조합형 민간임대주택 추가분담금 늘어나기에 전액환불 단순변심으로 법적 갈등.txt 파일이 팀장님 폴더에 복사되었습니다.
# 82_지주택탈퇴 전액환불 허위광고로 위약금없이 힘들다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 83_지역주택조합탈퇴 잔금납부 불가능해 단순변심으로 반환청구 승소 승소 노하우.txt 파일이 이사님 폴더에 복사되었습니다.
# 84_지역주택조합탈퇴 마이너스피로 잔금납부 불가능해 단체소송 출장상담.txt 파일이 팀장님 폴더에 복사되었습니다.
# 85_지역주택조합탈퇴 전액환불 허위광고로 중도금이자 마련 법적 갈등.txt 파일이 주휘 폴더에 복사되었습니다.
# 86_지역주택조합탈퇴 전액환불 단순변심으로 추가분담금 늘어나기에 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 87_지역주택조합탈퇴 추후의 변심으로 잔금납부 불가능해 단체소송 출장상담.txt 파일이 팀장님 폴더에 복사되었습니다.
# 88_협동조합형 민간임대주택 허위광고로 잔금납부 불가능해 단체소송 승소 노하우.txt 파일이 주휘 폴더에 복사되었습니다.
# 89_협동조합형 민간임대주택 추후의 변심으로 중도금이자 마련 전액환불 출장상담.txt 파일이 이사님 폴더에 복사되었습니다.
# 8_지역주택조합탈퇴 중도금이자 마련 추후의 변심으로 전액환불 출장상담.txt 파일이 팀장님 폴더에 복사되었습니다.
# 90_협동조합형 민간임대주택 반환청구 승소 중도금이자 마련 공사지연으로 힘들다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 91_협동조합형 민간임대주택 위약금없이 시세하락으로 인해 분양권취소 고민된다면.txt 파일이 이사님 폴더에 복사되었습니다.
# 92_지역주택조합탈퇴 추가분담금 늘어나기에 추후의 변심으로 분양포기 힘들다면.txt 파일이 팀장님 폴더에 복사되었습니다.
# 93_지역주택조합탈퇴 중도금이자 마련 추후의 변심으로 분양포기 힘들다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 94_협동조합형 민간임대주택 허위광고로 추가분담금 늘어나기에 분양권취소 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
# 95_지역주택조합탈퇴 위약금없이 단순변심으로 전액환불 법적 갈등.txt 파일이 팀장님 폴더에 복사되었습니다.
# 96_지역주택조합탈퇴 반환청구 승소 잔금납부 불가능해 공사지연으로 고민된다면.txt 파일이 주휘 폴더에 복사되었습니다.
# 97_협동조합형 민간임대주택 시세하락으로 인해 위약금없이 분양포기 힘들다면.txt 파일이 이사님 폴더에 복사되었습니다.
# 98_지주택탈퇴 단순변심으로 중도금이자 마련 반환청구 승소 승소 노하우.txt 파일이 팀장님 폴더에 복사되었습니다.
# 99_지주택탈퇴 반환청구 승소 중도금이자 마련 마이너스피로 법적 갈등.txt 파일이 주휘 폴더에 복사되었습니다.
# 9_지주택탈퇴 시세하락으로 인해 잔금납부 불가능해 반환청구 승소 법적 갈등.txt 파일이 이사님 폴더에 복사되었습니다.
#
# 모든 파일 생성 및 배분이 완료되었습니다.

# %% [markdown]
# 여기서 또 돌리게 되면, 'synonym'을 이용해서 치환한 파일들이 저장됩니다.
# 아까 설정했던 base_word인 '법인회생' 폴더 안에, '오늘날짜 및 시간' 폴더 안에 전체가 저장되었습니다.

# %% [markdown]
# 그럼 이제 이걸 사람들에게 나누어야겠죠.

# %% [markdown]
# 결과적으로 법인회생 배분 폴더 안에 날짜/시간 폴더 안에 사람마다 배분되었습니다.
# 이제 구글드라이브에 올려 함께 이용하면 됩니다.
#
# 주의!!
# '법인회생', '분양권해지' 이런 애들은 한번 거쳐가는 폴더이므로 실제 사용할 때는 '~배분'으로 끝나는 폴더를 봐 주세요.
