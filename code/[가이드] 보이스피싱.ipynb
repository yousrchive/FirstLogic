# %% [markdown]
# 하나 쭉 시도하고 하나 쭉 시도하면 겹치지 않는 여러개가 만들어집니다.
# 현재는 한 번에 50개를 생성하도록 설정해두었습니다
# shift + enter를 이용해 하나하나 실행할 수 있습니다.

# %%
import random
import os
from datetime import datetime

# %% [markdown]
# #시작하기 전에 원고에 대체할 키워드가 몇 개 들어가있는지 확인하는 작업입니다.
#
# 새로운 원고를 생성하고 싶다면?
# 1) 이 폴더 안에 텍스트 파일을 생성하시고(왼쪽 바에 우클릭, 뉴파일 생성, '원하는 제목'.txt로 이름 변경)
# 2) 아래 with open('C:/Users/user/Desktop/원고치환/원본/법인회생.txt', 'r', encoding='utf-8') as file:
#     text = file.read()
# 이 부분에서 법인회생.txt 부분을 바꾸시면 됩니다.
# (ex. 지역주택조합.txt {내가입력했던것}.txt)

# %%
# 특정 단어와 대체어 리스트 정의
base_word = '버스성추행' #핵심 단어를 정의하세요.

# 텍스트 파일 읽기
with open('C:/Users/user/Desktop/원고치환/원본/버스성추행.txt', 'r', encoding='utf-8') as file:
    input_file = file.read() #/버스성추행.txt를 텍스트파일 제목으로 갖고오세요.

# 단어 개수 세기
count = input_file.count(base_word)

# 결과 출력
print(f"'{base_word}'는 텍스트 파일에 {count}번 등장합니다.")
# Out:
# '버스성추행'는 텍스트 파일에 8번 등장합니다.

# %% [markdown]
# #아래는 위에 입력한 '법인회생(예)'이라는 단어를 무슨 단어로 바꿀 것인지를 정의했습니다.
# 각 리스트에서 하나씩 빼 와서 하나의 말뭉치를 만드는 과정입니다.
# 만약 지역에 '동탄'을 추가하고 싶으면, 리스트 첫번째 줄에 추가해주세요.
# 비슷한 느낌이 드는 단어들에 추가해주시면 됩니다.

# %%
import random

lists = [
    ['보이스피싱', '보이스피싱인출책', '보이스피싱현금수거책', '보이스피싱중간책', '보이스피싱 연루'],
    ['초범', '무혐의', '초범무혐의', '중간책', '특경사기 혐의', '단순 가담'],
    ['현행범체포', '경찰조사', '구속영장', '처벌 수위'],
    ['처벌불원서', '반성문', '탄원서'],
    ['변호사 선임', '법적대처', '대응방법', '무죄판결', '처벌최소화', '수사 과정']
] #마찬가지로, 뺑뺑이를 돌면서 제목을 만들 단어이자 핵심단어를 대체할 단어집을 만들겠습니다.

# 모든 가능한 문장들을 담을 리스트
requirement_words = []

# 모든 가능한 조합 생성
for _ in range(100):  # 예시로 100개 문장 생성
    # 첫 번째 리스트에서 요소 선택
    sentence_parts = []
    sentence_parts.append(random.choice(lists[0]))

    # 나머지 리스트에서 요소 선택
    for i in random.sample(range(1, 4), 3):  # lists[1], lists[2], lists[3]에서 랜덤하게 3개 선택
        sentence_parts.append(random.choice(lists[i]))

    # 마지막 리스트에서 요소 선택
    sentence_parts.append(random.choice(lists[4]))

    # 문장 생성 및 저장
    sentence = ' '.join(sentence_parts)
    requirement_words.append(sentence)

# 결과 확인
for idx, sentence in enumerate(requirement_words, start=1):
    print(f"{idx}. {sentence}")

big_folder_name = lists[0][0]
# Out:
# 1. 보이스피싱현금수거책 처벌 수위 반성문 초범 수사 과정
# 2. 보이스피싱 구속영장 특경사기 혐의 탄원서 수사 과정
# 3. 보이스피싱 연루 반성문 무혐의 경찰조사 대응방법
# 4. 보이스피싱현금수거책 특경사기 혐의 반성문 경찰조사 처벌최소화
# 5. 보이스피싱중간책 반성문 단순 가담 현행범체포 대응방법
# 6. 보이스피싱현금수거책 탄원서 초범무혐의 처벌 수위
# 실제로 단어를 바꾸는 과정입니다.
# 여기에는 'synonym.txt'라는 파일(좌측 바에 있음)을 사용하므로, 수정하고 싶으면 거기서 수정해주세요.
# 저장하고 돌리는 것은 필수

# %%
from datetime import datetime
current_date = datetime.now().strftime("%Y%m%d_%H%M")

# %%
import random
import os
import shutil
from datetime import datetime

# 전역 변수로 output_folder 선언
output_folder = ""

# 대체어 딕셔너리를 읽어오는 함수
def read_synonyms(filename):
    synonyms_dict = {}
    with open(filename, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.split(':')
            if len(parts) == 2:
                word = parts[0].strip().strip("'")
                synonyms = parts[1].strip().strip('[]\n').replace("'", "").split(', ')
                synonyms_dict[word] = synonyms
    return synonyms_dict

# 입력 텍스트 파일 처리 함수
def replace_words_with_synonyms(text, synonyms_dict):
    for word, synonyms in synonyms_dict.items():
        if word in text:
            text = text.replace(word, random.choice(synonyms))
    return text

# 추가된 단어 치환 및 파일 생성 함수
def replace_and_generate_files(input_file, base_word, requirement_words, synonyms_dict):
    global output_folder  # 전역 변수로 선언
    
    # 현재 날짜와 시간을 포맷에 맞게 생성
    current_date = datetime.now().strftime("%Y%m%d_%H%M")
    
    # 결과를 저장할 폴더 생성
    output_folder = os.path.join(base_word, current_date)
    os.makedirs(output_folder, exist_ok=True)
    
    # 각 requirement_word 별로 파일 생성
    for i, replacement in enumerate(requirement_words):
        modified_text = input_file.replace(base_word, replacement)
        modified_text = replace_words_with_synonyms(modified_text, synonyms_dict)
        
        # 파일명에 순서 번호를 붙여 겹치지 않게 만듦
        output_filename = os.path.join(output_folder, f"{i + 1}_{replacement}.txt")
        with open(output_filename, 'w', encoding='utf-8') as file:
            file.write(modified_text)
        print(f"{output_filename} 파일이 생성되었습니다.")

# 함수 정의: 원고 파일을 각 수신자에게 배분하는 함수
def distribute_files_to_recipients(input_folder, recipients, base_word, current_date):
    # 배분 기본 폴더
    base_folder = f'{base_word} 배분'

    # 각 수신자 폴더 경로 생성
    for recipient in recipients:
        recipient_folder = os.path.join(base_folder, current_date, recipient)
        os.makedirs(recipient_folder, exist_ok=True)

    file_list = sorted(os.listdir(input_folder))

    num_recipients = len(recipients)
    files_per_recipient = len(file_list) // num_recipients

    for i, file_name in enumerate(file_list):
        if file_name.endswith('.txt'):
            src = os.path.join(input_folder, file_name)
            recipient_index = i % num_recipients
            recipient = recipients[recipient_index]
            dst = os.path.join(base_folder, current_date, recipient, file_name)
            shutil.copy(src, dst)
            print(f"{file_name} 파일이 {recipient} 폴더에 복사되었습니다.")

# 대체어 딕셔너리 읽기
synonyms_dict = read_synonyms('synonym.txt')

recipients = ['이사님', '팀장님', '주휘']

# 파일 생성 함수 호출
replace_and_generate_files(input_file, base_word, requirement_words, synonyms_dict)

# 생성된 파일 목록 출력
if output_folder:
    print(f"\n폴더 '{output_folder}'의 내용:")
    for filename in os.listdir(output_folder):
        print(filename)

# 파일 배분 함수 호출
input_folder = rf'C:\Users\user\Desktop\원고치환\{output_folder}'
distribute_files_to_recipients(input_folder, recipients, base_word, datetime.now().strftime("%Y%m%d_%H%M"))

print("\n모든 파일 생성 및 배분이 완료되었습니다.")
# Out:
# 버스성추행\20240719_1422\1_보이스피싱현금수거책 처벌 수위 반성문 초범 수사 과정.txt 파일이 생성되었습니다.
# 버스성추행\20240719_1422
법적대처.txt 파일이 주휘 폴더에 복사되었습니다.
# 72_보이스피싱인출책 구속영장 처벌불원서 초범무혐의 법적대처.txt 파일이 이사님 폴더에 복사되었습니다.
# 73_보이스피싱 처벌 수위 반성문 초범 변호사 선임.txt 파일이 팀장님 폴더에 복사되었습니다.
# 74_보이스피싱 초범 처벌불원서 현행범체포 법적대처.txt 파일이 주휘 폴더에 복사되었습니다.
# 75_보이스피싱현금수거책 처벌불원서 현행범체포 무혐의 처벌최소화.txt 파일이 이사님 폴더에 복사되었습니다.
# 76_보이스피싱인출책 처벌불원서 단순 가담 경찰조사 무죄판결.txt 파일이 팀장님 폴더에 복사되었습니다.
# 77_보이스피싱현금수거책 처벌 수위 초범무혐의 처벌불원서 변호사 선임.txt 파일이 주휘 폴더에 복사되었습니다.
# 78_보이스피싱중간책 현행범체포 탄원서 특경사기 혐의 무죄판결.txt 파일이 이사님 폴더에 복사되었습니다.
# 79_보이스피싱인출책 처벌불원서 경찰조사 무혐의 대응방법.txt 파일이 팀장님 폴더에 복사되었습니다.
# 7_보이스피싱 처벌불원서 중간책 처벌 수위 수사 과정.txt 파일이 주휘 폴더에 복사되었습니다.
# 80_보이스피싱인출책 단순 가담 구속영장 탄원서 무죄판결.txt 파일이 이사님 폴더에 복사되었습니다.
# 81_보이스피싱인출책 초범무혐의 처벌불원서 구속영장 법적대처.txt 파일이 팀장님 폴더에 복사되었습니다.
# 82_보이스피싱인출책 구속영장 특경사기 혐의 처벌불원서 수사 과정.txt 파일이 주휘 폴더에 복사되었습니다.
# 83_보이스피싱 연루 처벌불원서 현행범체포 중간책 법적대처.txt 파일이 이사님 폴더에 복사되었습니다.
# 84_보이스피싱인출책 반성문 단순 가담 경찰조사 법적대처.txt 파일이 팀장님 폴더에 복사되었습니다.
# 85_보이스피싱 연루 탄원서 특경사기 혐의 처벌 수위 법적대처.txt 파일이 주휘 폴더에 복사되었습니다.
# 86_보이스피싱 연루 반성문 처벌 수위 무혐의 법적대처.txt 파일이 이사님 폴더에 복사되었습니다.
# 87_보이스피싱 연루 처벌불원서 경찰조사 중간책 수사 과정.txt 파일이 팀장님 폴더에 복사되었습니다.
# 88_보이스피싱 연루 처벌불원서 현행범체포 초범 변호사 선임.txt 파일이 주휘 폴더에 복사되었습니다.
# 89_보이스피싱 연루 탄원서 처벌 수위 초범 법적대처.txt 파일이 이사님 폴더에 복사되었습니다.
# 8_보이스피싱현금수거책 구속영장 처벌불원서 무혐의 처벌최소화.txt 파일이 팀장님 폴더에 복사되었습니다.
# 90_보이스피싱인출책 처벌 수위 초범 반성문 수사 과정.txt 파일이 주휘 폴더에 복사되었습니다.
# 91_보이스피싱현금수거책 경찰조사 중간책 반성문 변호사 선임.txt 파일이 이사님 폴더에 복사되었습니다.
# 92_보이스피싱 연루 경찰조사 탄원서 초범 수사 과정.txt 파일이 팀장님 폴더에 복사되었습니다.
# 93_보이스피싱 연루 구속영장 반성문 특경사기 혐의 법적대처.txt 파일이 주휘 폴더에 복사되었습니다.
# 94_보이스피싱인출책 현행범체포 처벌불원서 무혐의 처벌최소화.txt 파일이 이사님 폴더에 복사되었습니다.
# 95_보이스피싱현금수거책 특경사기 혐의 처벌불원서 구속영장 대응방법.txt 파일이 팀장님 폴더에 복사되었습니다.
# 96_보이스피싱현금수거책 초범 처벌 수위 탄원서 법적대처.txt 파일이 주휘 폴더에 복사되었습니다.
# 97_보이스피싱중간책 반성문 경찰조사 단순 가담 대응방법.txt 파일이 이사님 폴더에 복사되었습니다.
# 98_보이스피싱현금수거책 처벌 수위 반성문 초범 처벌최소화.txt 파일이 팀장님 폴더에 복사되었습니다.
# 99_보이스피싱 연루 탄원서 경찰조사 무혐의 수사 과정.txt 파일이 주휘 폴더에 복사되었습니다.
# 9_보이스피싱인출책 처벌불원서 경찰조사 중간책 무죄판결.txt 파일이 이사님 폴더에 복사되었습니다.
#
# 모든 파일 생성 및 배분이 완료되었습니다.

# %% [markdown]
# 여기서 또 돌리게 되면, 'synonym'을 이용해서 치환한 파일들이 저장됩니다.
# 아까 설정했던 base_word인 '법인회생' 폴더 안에, '오늘날짜 및 시간' 폴더 안에 전체가 저장되었습니다.

# %% [markdown]
# 그럼 이제 이걸 사람들에게 나누어야겠죠.

# %%
결과적으로 법인회생 배분 폴더 안에 날짜/시간 폴더 안에 사람마다 배분되었습니다.
이제 구글드라이브에 올려 함께 이용하면 됩니다.
