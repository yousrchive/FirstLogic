# %% [markdown]
# 하나 쭉 시도하고 하나 쭉 시도하면 겹치지 않는 여러개가 만들어집니다.
# 현재는 한 번에 50개를 생성하도록 설정해두었습니다
# shift + enter를 이용해 하나하나 실행할 수 있습니다.

# %%
import random
import os
from datetime import datetime

# %% [markdown]
# #시작하기 전에 원고에 대체할 키워드가 몇 개 들어가있는지 확인하는 작업입니다.
#
# 새로운 원고를 생성하고 싶다면?
# 1) 이 폴더 안에 텍스트 파일을 생성하시고(왼쪽 바에 우클릭, 뉴파일 생성, '원하는 제목'.txt로 이름 변경)
# 2) 아래 with open('C:/Users/user/Desktop/원고치환/원본/법인회생.txt', 'r', encoding='utf-8') as file:
#     text = file.read()
# 이 부분에서 법인회생.txt 부분을 바꾸시면 됩니다.
# (ex. 지역주택조합.txt {내가입력했던것}.txt)

# %%
# 특정 단어와 대체어 리스트 정의
base_word = '버스성추행'

# 텍스트 파일 읽기
with open('C:/Users/user/Desktop/원고치환/원본/버스성추행.txt', 'r', encoding='utf-8') as file:
    input_file = file.read()

# 단어 개수 세기
count = input_file.count(base_word)

# 결과 출력
print(f"'{base_word}'는 텍스트 파일에 {count}번 등장합니다.")
# Out:
# '버스성추행'는 텍스트 파일에 8번 등장합니다.

# %% [markdown]
# #아래는 위에 입력한 '법인회생(예)'이라는 단어를 무슨 단어로 바꿀 것인지를 정의했습니다.
# 각 리스트에서 하나씩 빼 와서 하나의 말뭉치를 만드는 과정입니다.
# 만약 지역에 '동탄'을 추가하고 싶으면, 리스트 첫번째 줄에 추가해주세요.
# 비슷한 느낌이 드는 단어들에 추가해주시면 됩니다.

# %%
import random

lists = [
    ['군인성추행', '마약변호사', '지하철성추행', '카메라등이용촬영죄', '클럽성추행', '공중밀집장소추행', '버스성추행', '보이스피싱', '음주운전뺑소니'],
    ['초범', '무혐의', '초범무혐의', '중간책', '특경사기혐의'],
    ['현행범체포', '경찰조사', '구속영장'],
    ['처벌불원서', '반성문', '탄원서'],
    ['변호사 선임', '법적대처', '대응방법']
]

# 모든 가능한 문장들을 담을 리스트
requirement_words = []

# 모든 가능한 조합 생성
for _ in range(150):  # 예시로 100개 문장 생성
    # 첫 번째 리스트에서 요소 선택
    sentence_parts = []
    sentence_parts.append(random.choice(lists[0]))

    # 나머지 리스트에서 요소 선택
    for i in random.sample(range(1, 4), 3):  # lists[1], lists[2], lists[3]에서 랜덤하게 3개 선택
        sentence_parts.append(random.choice(lists[i]))

    # 마지막 리스트에서 요소 선택
    sentence_parts.append(random.choice(lists[4]))

    # 문장 생성 및 저장
    sentence = ' '.join(sentence_parts)
    requirement_words.append(sentence)

# 결과 확인
for idx, sentence in enumerate(requirement_words, start=1):
    print(f"{idx}. {sentence}")
# Out:
# 1. 보이스피싱 경찰조사 무혐의 처벌불원서 법적대처
# 2. 보이스피싱 특경사기혐의 탄원서 구속영장 변호사 선임
# 3. 지하철성추행 현행범체포 반성문 특경사기혐의 법적대처
# 4. 지하철성추행 구속영장 처벌불원서 특경사기혐의 법적대처
# 133. 카메라등이용촬영죄 경찰조사 무혐의 탄원서 대응방법
# 134. 음주운전뺑소니 구속영장 초범 탄원서 법적대처
# 135. 클럽성추행 탄원서 현행범체포 특경사기혐의 대응방법
# 136. 마약변호사 경찰조사 초범 탄원서 대응방법
# 137. 클럽성추행 현행범체포 중간책 반성문 대응방법
# 138. 마약변호사 탄원서 초범무혐의 경찰조사 변호사 선임
# 139. 공중밀집장소추행 중간책 경찰조사 처벌불원서 변호사 선임
# 140. 지하철성추행 초범무혐의 처벌불원서 경찰조사 대응방법
# 141. 지하철성추행 경찰조사 초범무혐의 탄원서 대응방법
# 142. 음주운전뺑소니 특경사기혐의 탄원서 현행범체포 대응방법
# 143. 보이스피싱 탄원서 무혐의 경찰조사 변호사 선임
# 144. 버스성추행 구속영장 무혐의 반성문 변호사 선임
# 145. 군인성추행 초범 처벌불원서 경찰조사 대응방법
# 146. 보이스피싱 초범 구속영장 탄원서 법적대처
# 147. 클럽성추행 무혐의 탄원서 구속영장 변호사 선임
# 148. 지하철성추행 탄원서 구속영장 특경사기혐의 대응방법
# 149. 클럽성추행 탄원서 초범무혐의 현행범체포 대응방법
# 150. 군인성추행 탄원서 중간책 현행범체포 대응방법

# %% [markdown]
# 이렇게 제목들이 만들어졌습니다. 앞으로 '버스성추행' 대신에 저것이 쓰일 것입니다.

# %%
requirement_words
# Out:
# ['지하철성추행 구속영장 초범무혐의 탄원서 대응방법',
#  '마약변호사 현행범체포 초범무혐의 처벌불원서 변호사 선임',
#  '음주운전뺑소니 특경사기혐의 반성문 현행범체포 대응방법',
#  '마약변호사 현행범체포 처벌불원서 중간책 대응방법',
#  '클럽성추행 구속영장 중간책 처벌불원서 법적대처',
#  '버스성추행 탄원서 특경사기혐의 구속영장 법적대처',
#  '지하철성추행 특경사기혐의 반성문 구속영장 대응방법',
#  '음주운전뺑소니 현행범체포 처벌불원서 초범 법적대처',
#  '클럽성추행 현행범체포 처벌불원서 초범무혐의 법적대처',
#  '버스성추행 현행범체포 중간책 처벌불원서 대응방법',
#  '클럽성추행 초범무혐의 현행범체포 처벌불원서 법적대처',
#  '군인성추행 경찰조사 처벌불원서 중간책 변호사 선임',
#  '버스성추행 무혐의 구속영장 반성문 대응방법',
#  '군인성추행 현행범체포 특경사기혐의 처벌불원서 변호사 선임',
#  '공중밀집장소추행 처벌불원서 구속영장 무혐의 변호사 선임',
#  '카메라등이용촬영죄 반성문 특경사기혐의 현행범체포 변호사 선임',
#  '버스성추행 구속영장 처벌불원서 초범 대응방법',
#  '카메라등이용촬영죄 구속영장 처벌불원서 무혐의 법적대처',
#  '클럽성추행 탄원서 초범 현행범체포 변호사 선임',
#  '지하철성추행 처벌불원서 현행범체포 초범 대응방법',
#  '보이스피싱 초범 현행범체포 반성문 대응방법',
#  '버스성추행 처벌불원서 특경사기혐의 경찰조사 대응방법',
#  '음주운전뺑소니 반성문 경찰조사 특경사기혐의 법적대처',
#  '군인성추행 반성문 초범 구속영장 대응방법',
#  '보이스피싱 현행범체포 탄원서 초범 법적대처',
#  '군인성추행 구속영장 초범무혐의 탄원서 대응방법',
#  '군인성추행 현행범체포 특경사기혐의 탄원서 대응방법',
#  '마약변호사 현행범체포 특경사기혐의 탄원서 법적대처',
#  '공중밀집장소추행 반성문 중간책 구속영장 변호사 선임',
#  '지하철성추행 처벌불원서 구속영장 초범무혐의 변호사 선임',
#  '공중밀집장소추행 탄원서 중간책 경찰조사 변호사 선임',
#  '공중밀집장소추행 특경사기혐의 탄원서 현행범체포 대응방법',
#  '마약변호사 탄원서 구속영장 중간책 대응방법',
#  '버스성추행 초범 구속영장 반성문 변호사 선임',
#  '카메라등이용촬영죄 현행범체포 중간책 탄원서 대응방법',
#  '군인성추행 무혐의 구속영장 반성문 법적대처',
#  '클럽성추행 초범무혐의 현행범체포 탄원서 법적대처',
#  '카메라등이용촬영죄 초범무혐의 처벌불원서 경찰조사 변호사 선임',
#  '지하철성추행 구속영장 초범 탄원서 법적대처',
#  '보이스피싱 중간책 경찰조사 반성문 법적대처',
#  '버스성추행 특경사기혐의 탄원서 구속영장 법적대처',
#  '보이스피싱 반성문 특경사기혐의 구속영장 법적대처',
#  '버스성추행 경찰조사 특경사기혐의 반성문 법적대처',
#  '마약변호사 반성문 중간책 경찰조사 법적대처',
#  '마약변호사 반성문 초범무혐의 경찰조사 법적대처',
#  '버스성추행 현행범체포 무혐의 반성문 대응방법',
#  '버스성추행 경찰조사 초범 처벌불원서 법적대처',
#  '지하철성추행 중간책 처벌불원서 경찰조사 대응방법',
#  '버스성추행 경찰조사 특경사기혐의 반성문 대응방법',
#  '지하철성추행 반성문 현행범체포 무혐의 대응방법',
#  '공중밀집장소추행 구속영장 처벌불원서 중간책 대응방법',
#  '카메라등이용촬영죄 처벌불원서 구속영장 초범무혐의 법적대처',
#  '카메라등이용촬영죄 반성문 경찰조사 중간책 대응방법',
#  '보이스피싱 중간책 탄원서 현행범체포 변호사 선임',
#  '지하철성추행 특경사기혐의 탄원서 구속영장 법적대처',
#  '지하철성추행 반성문 구속영장 중간책 변호사 선임',
#  '공중밀집장소추행 특경사기혐의 구속영장 처벌불원서 대응방법',
#  '지하철성추행 중간책 경찰조사 처벌불원서 변호사 선임',
#  '지하철성추행 현행범체포 처벌불원서 무혐의 변호사 선임',
#  '마약변호사 경찰조사 초범무혐의 반성문 변호사 선임',
#  '보이스피싱 탄원서 특경사기혐의 구속영장 법적대처',
#  '음주운전뺑소니 초범무혐의 처벌불원서 현행범체포 변호사 선임',
#  '공중밀집장소추행 중간책 반성문 현행범체포 변호사 선임',
#  '음주운전뺑소니 무혐의 탄원서 경찰조사 법적대처',
#  '보이스피싱 초범무혐의 경찰조사 반성문 법적대처',
#  '군인성추행 반성문 현행범체포 중간책 대응방법',
#  '버스성추행 현행범체포 초범무혐의 탄원서 변호사 선임',
#  '지하철성추행 처벌불원서 구속영장 무혐의 변호사 선임',
#  '음주운전뺑소니 탄원서 무혐의 현행범체포 변호사 선임',
#  '카메라등이용촬영죄 경찰조사 처벌불원서 초범 법적대처',
#  '마약변호사 특경사기혐의 탄원서 경찰조사 법적대처',
#  '마약변호사 처벌불원서 경찰조사 특경사기혐의 법적대처',
#  '음주운전뺑소니 처벌불원서 구속영장 특경사기혐의 법적대처',
#  '음주운전뺑소니 반성문 특경사기혐의 경찰조사 법적대처',
#  '음주운전뺑소니 특경사기혐의 반성문 구속영장 대응방법',
#  '마약변호사 탄원서 현행범체포 초범무혐의 변호사 선임',
#  '버스성추행 처벌불원서 중간책 경찰조사 대응방법',
#  '공중밀집장소추행 특경사기혐의 반성문 구속영장 변호사 선임',
#  '군인성추행 무혐의 반성문 현행범체포 변호사 선임',
#  '공중밀집장소추행 중간책 경찰조사 반성문 대응방법',
#  '지하철성추행 구속영장 처벌불원서 초범 변호사 선임',
#  '공중밀집장소추행 구속영장 무혐의 탄원서 변호사 선임',
#  '클럽성추행 구속영장 탄원서 무혐의 대응방법',
#  '버스성추행 중간책 현행범체포 처벌불원서 법적대처',
#  '클럽성추행 현행범체포 초범무혐의 반성문 대응방법',
#  '공중밀집장소추행 구속영장 초범무혐의 반성문 변호사 선임',
#  '클럽성추행 구속영장 반성문 중간책 변호사 선임',
#  '보이스피싱 무혐의 경찰조사 반성문 법적대처',
#  '보이스피싱 반성문 경찰조사 초범무혐의 변호사 선임',
#  '클럽성추행 초범 탄원서 현행범체포 대응방법',
#  '마약변호사 초범무혐의 경찰조사 반성문 법적대처',
#  '지하철성추행 구속영장 처벌불원서 초범무혐의 법적대처',
#  '마약변호사 초범무혐의 구속영장 탄원서 대응방법',
#  '보이스피싱 중간책 처벌불원서 구속영장 대응방법',
#  '클럽성추행 특경사기혐의 경찰조사 반성문 법적대처',
#  '군인성추행 반성문 현행범체포 무혐의 대응방법',
#  '공중밀집장소추행 특경사기혐의 경찰조사 반성문 변호사 선임',
#  '음주운전뺑소니 반성문 특경사기혐의 현행범체포 변호사 선임',
#  '마약변호사 특경사기혐의 처벌불원서 구속영장 대응방법',
#  '군인성추행 경찰조사 탄원서 무혐의 법적대처',
#  '보이스피싱 반성문 초범 현행범체포 법적대처',
#  '카메라등이용촬영죄 중간책 반성문 구속영장 변호사 선임',
#  '군인성추행 구속영장 무혐의 처벌불원서 법적대처',
#  '클럽성추행 처벌불원서 경찰조사 중간책 변호사 선임',
#  '군인성추행 탄원서 현행범체포 초범무혐의 변호사 선임',
#  '마약변호사 특경사기혐의 구속영장 처벌불원서 변호사 선임',
#  '보이스피싱 현행범체포 반성문 무혐의 대응방법',
#  '지하철성추행 경찰조사 초범무혐의 반성문 변호사 선임',
#  '마약변호사 탄원서 구속영장 특경사기혐의 법적대처',
#  '지하철성추행 탄원서 현행범체포 초범 대응방법',
#  '클럽성추행 특경사기혐의 탄원서 구속영장 법적대처',
#  '지하철성추행 무혐의 반성문 구속영장 변호사 선임',
#  '음주운전뺑소니 경찰조사 처벌불원서 중간책 대응방법',
#  '공중밀집장소추행 초범 처벌불원서 경찰조사 변호사 선임',
#  '공중밀집장소추행 탄원서 경찰조사 중간책 변호사 선임',
#  '공중밀집장소추행 처벌불원서 경찰조사 초범 변호사 선임',
#  '군인성추행 초범무혐의 현행범체포 반성문 법적대처',
#  '클럽성추행 무혐의 반성문 경찰조사 변호사 선임',
#  '공중밀집장소추행 중간책 구속영장 반성문 법적대처',
#  '버스성추행 무혐의 반성문 구속영장 대응방법',
#  '클럽성추행 무혐의 경찰조사 탄원서 법적대처',
#  '카메라등이용촬영죄 현행범체포 탄원서 초범 변호사 선임',
#  '버스성추행 중간책 반성문 구속영장 대응방법',
#  '음주운전뺑소니 반성문 경찰조사 특경사기혐의 법적대처',
#  '공중밀집장소추행 경찰조사 무혐의 반성문 법적대처',
#  '클럽성추행 반성문 구속영장 초범무혐의 변호사 선임',
#  '군인성추행 초범무혐의 반성문 현행범체포 변호사 선임',
#  '공중밀집장소추행 초범 처벌불원서 현행범체포 법적대처',
#  '지하철성추행 초범무혐의 탄원서 경찰조사 법적대처',
#  '공중밀집장소추행 구속영장 탄원서 중간책 변호사 선임',
#  '지하철성추행 초범 현행범체포 반성문 법적대처',
#  '버스성추행 경찰조사 반성문 특경사기혐의 변호사 선임',
#  '지하철성추행 탄원서 무혐의 현행범체포 대응방법',
#  '카메라등이용촬영죄 특경사기혐의 탄원서 구속영장 법적대처',
#  '마약변호사 초범 처벌불원서 현행범체포 대응방법',
#  '마약변호사 반성문 특경사기혐의 구속영장 변호사 선임',
#  '카메라등이용촬영죄 초범 처벌불원서 현행범체포 법적대처',
#  '지하철성추행 반성문 구속영장 무혐의 변호사 선임',
#  '마약변호사 경찰조사 무혐의 반성문 변호사 선임',
#  '마약변호사 경찰조사 무혐의 처벌불원서 변호사 선임',
#  '공중밀집장소추행 초범무혐의 처벌불원서 구속영장 변호사 선임',
#  '공중밀집장소추행 초범무혐의 경찰조사 처벌불원서 법적대처',
#  '공중밀집장소추행 구속영장 반성문 중간책 대응방법',
#  '공중밀집장소추행 현행범체포 특경사기혐의 탄원서 변호사 선임',
#  '마약변호사 구속영장 초범 탄원서 변호사 선임',
#  '지하철성추행 구속영장 반성문 무혐의 대응방법',
#  '클럽성추행 현행범체포 중간책 탄원서 변호사 선임',
#  '버스성추행 무혐의 경찰조사 처벌불원서 법적대처',
#  '음주운전뺑소니 탄원서 경찰조사 중간책 변호사 선임',
#  '지하철성추행 반성문 경찰조사 특경사기혐의 변호사 선임']

# %% [markdown]
# 확인해보니 잘 나왔습니다. 특히나 이번 원고는 제목이 '버스성추행은'이기 때문에 마지막 단어를 명사로 정해두는 것이 중요합니다.

# %% [markdown]
# 아래는 원래 하던 것처럼, A씨를 E씨로 바꾸고... 유사도를 낮추려 바꿀 단어 리스트를 이용해
# 실제로 단어를 바꾸는 과정입니다.
# 여기에는 'synonym.txt'라는 파일(좌측 바에 있음)을 사용하므로, 수정하고 싶으면 거기서 수정해주세요.
# 저장하고 돌리는 것은 필수

# %%
current_date = datetime.now().strftime("%Y%m%d_%H%M")

# %%
import random
import os
import shutil
from datetime import datetime

# 전역 변수로 output_folder 선언
output_folder = ""

# 대체어 딕셔너리를 읽어오는 함수
def read_synonyms(filename):
    synonyms_dict = {}
    with open(filename, 'r', encoding='utf-8') as file:
        for line in file:
            parts = line.split(':')
            if len(parts) == 2:
                word = parts[0].strip().strip("'")
                synonyms = parts[1].strip().strip('[]\n').replace("'", "").split(', ')
                synonyms_dict[word] = synonyms
    return synonyms_dict

# 입력 텍스트 파일 처리 함수
def replace_words_with_synonyms(text, synonyms_dict):
    for word, synonyms in synonyms_dict.items():
        if word in text:
            text = text.replace(word, random.choice(synonyms))
    return text

# 추가된 단어 치환 및 파일 생성 함수
def replace_and_generate_files(input_file, base_word, requirement_words, synonyms_dict):
    global output_folder  # 전역 변수로 선언
    
    # 현재 날짜와 시간을 포맷에 맞게 생성
    current_date = datetime.now().strftime("%Y%m%d_%H%M")
    
    # 결과를 저장할 폴더 생성
    output_folder = os.path.join(base_word, current_date)
    os.makedirs(output_folder, exist_ok=True)
    
    # 각 requirement_word 별로 파일 생성
    for i, replacement in enumerate(requirement_words):
        modified_text = input_file.replace(base_word, replacement)
        modified_text = replace_words_with_synonyms(modified_text, synonyms_dict)
        
        # 파일명에 순서 번호를 붙여 겹치지 않게 만듦
        output_filename = os.path.join(output_folder, f"{i + 1}_{replacement}.txt")
        with open(output_filename, 'w', encoding='utf-8') as file:
            file.write(modified_text)
        print(f"{output_filename} 파일이 생성되었습니다.")

# 함수 정의: 원고 파일을 각 수신자에게 배분하는 함수
def distribute_files_to_recipients(input_folder, recipients, base_word, current_date):
    # 배분 기본 폴더
    base_folder = f'{base_word} 배분'

    # 각 수신자 폴더 경로 생성
    for recipient in recipients:
        recipient_folder = os.path.join(base_folder, current_date, recipient)
        os.makedirs(recipient_folder, exist_ok=True)

    file_list = sorted(os.listdir(input_folder))

    num_recipients = len(recipients)
    files_per_recipient = len(file_list) // num_recipients

    for i, file_name in enumerate(file_list):
        if file_name.endswith('.txt'):
            src = os.path.join(input_folder, file_name)
            recipient_index = i % num_recipients
            recipient = recipients[recipient_index]
            dst = os.path.join(base_folder, current_date, recipient, file_name)
            shutil.copy(src, dst)
            print(f"{file_name} 파일이 {recipient} 폴더에 복사되었습니다.")

# 대체어 딕셔너리 읽기
synonyms_dict = read_synonyms('synonym.txt')

recipients = ['이사님', '팀장님', '주휘']

# 파일 생성 함수 호출
replace_and_generate_files(input_file, base_word, requirement_words, synonyms_dict)

# 생성된 파일 목록 출력
if output_folder:
    print(f"\n폴더 '{output_folder}'의 내용:")
    for filename in os.listdir(output_folder):
        print(filename)

# 파일 배분 함수 호출
input_folder = rf'C:\Users\user\Desktop\원고치환\{output_folder}'
distribute_files_to_recipients(input_folder, recipients, base_word, datetime.now().strftime("%Y%m%d_%H%M"))

print("\n모든 파일 생성 및 배분이 완료되었습니다.")
# Out:
# 버스성추행\20240719_1417\1_보이스피싱 경찰조사 무혐의 처벌불원서 법적대처.txt 파일이 생성되었습니다.
# 버스성추행\20240719_1417\2_보이스피싱 특경사기혐의 탄원서 구속영장 변호사 선임.txt 파일이 생성되었습니다.
# 버스성추행\20240719_1417\3_지하철성추행 현행범체포 반성문 특경사기혐의 법적대처.txt 파일이 생성되었습니다.
# 버스성추행\20240719_1417
클럽성추행 구속영장 초범무혐의 반성문 대응방법.txt
# 28_클럽성추행 처벌불원서 경찰조사 초범무혐의 대응방법.txt
# 29_음주운전뺑소니 특경사기혐의 반성문 현행범체포 법적대처.txt
# 2_보이스피싱 특경사기혐의 탄원서 구속영장 변호사 선임.txt
# 30_군인성추행 무혐의 경찰조사 탄원서 대응방법.txt
# 31_공중밀집장소추행 현행범체포 초범 반성문 대응방법.txt
# 32_음주운전뺑소니 탄원서 현행범체포 초범 변호사 선임.txt
# 33_지하철성추행 초범 경찰조사 탄원서 대응방법.txt
# 34_음주운전뺑소니 초범무혐의 반성문 구속영장 대응방법.txt
# 35_버스성추행 특경사기혐의 구속영장 처벌불원서 대응방법.txt
# 36_카메라등이용촬영죄 처벌불원서 경찰조사 초범무혐의 대응방법.txt
# 37_보이스피싱 탄원서 초범무혐의 구속영장 변호사 선임.txt
# 38_음주운전뺑소니 현행범체포 처벌불원서 초범 대응방법.txt
# 39_마약변호사 처벌불원서 초범 현행범체포 대응방법.txt
# 3_지하철성추행 현행범체포 반성문 특경사기혐의 법적대처.txt
# 40_마약변호사 탄원서 특경사기혐의 현행범체포 법적대처.txt
# 41_공중밀집장소추행 현행범체포 초범무혐의 탄원서 법적대처.txt
# 42_군인성추행 처벌불원서 현행범체포 특경사기혐의 대응방법.txt
# 43_마약변호사 탄원서 초범무혐의 현행범체포 변호사 선임.txt
# 44_군인성추행 현행범체포 특경사기혐의 탄원서 법적대처.txt
# 45_마약변호사 탄원서 초범 구속영장 변호사 선임.txt
# 46_지하철성추행 초범무혐의 탄원서 현행범체포 대응방법.txt
# 47_버스성추행 구속영장 반성문 무혐의 법적대처.txt
# 48_보이스피싱 반성문 경찰조사 초범 변호사 선임.txt
# 49_공중밀집장소추행 특경사기혐의 반성문 구속영장 법적대처.txt
# 4_지하철성추행 구속영장 처벌불원서 특경사기혐의 법적대처.txt
# 50_클럽성추행 처벌불원서 현행범체포 초범무혐의 법적대처.txt
# 51_군인성추행 초범 탄원서 구속영장 법적대처.txt
# 52_클럽성추행 구속영장 반성문 특경사기혐의 법적대처.txt
# 53_음주운전뺑소니 특경사기혐의 처벌불원서 경찰조사 변호사 선임.txt
# 54_보이스피싱 처벌불원서 특경사기혐의 경찰조사 대응방법.txt
# 55_버스성추행 무혐의 탄원서 구속영장 변호사 선임.txt
# 56_지하철성추행 처벌불원서 구속영장 무혐의 법적대처.txt
# 57_클럽성추행 중간책 구속영장 처벌불원서 법적대처.txt
# 58_음주운전뺑소니 처벌불원서 구속영장 중간책 변호사 선임.txt
# 59_버스성추행 초범무혐의 구속영장 반성문 대응방법.txt
# 5_버스성추행 탄원서 구속영장 초범무혐의 변호사 선임.txt
# 60_버스성추행 구속영장 반성문 무혐의 대응방법.txt
# 61_지하철성추행 무혐의 구속영장 처벌불원서 법적대처.txt
# 62_음주운전뺑소니 탄원서 현행범체포 무혐의 대응방법.txt
대응방법.txt 파일이 이사님 폴더에 복사되었습니다.
# 69_음주운전뺑소니 구속영장 초범 처벌불원서 대응방법.txt 파일이 팀장님 폴더에 복사되었습니다.
# 6_군인성추행 초범무혐의 현행범체포 탄원서 법적대처.txt 파일이 주휘 폴더에 복사되었습니다.
# 70_지하철성추행 무혐의 탄원서 경찰조사 대응방법.txt 파일이 이사님 폴더에 복사되었습니다.
# 71_카메라등이용촬영죄 반성문 현행범체포 초범무혐의 변호사 선임.txt 파일이 팀장님 폴더에 복사되었습니다.
# 72_버스성추행 무혐의 탄원서 구속영장 변호사 선임.txt 파일이 주휘 폴더에 복사되었습니다.
# 73_클럽성추행 구속영장 반성문 초범무혐의 변호사 선임.txt 파일이 이사님 폴더에 복사되었습니다.
# 74_버스성추행 구속영장 중간책 탄원서 법적대처.txt 파일이 팀장님 폴더에 복사되었습니다.
# 75_지하철성추행 구속영장 탄원서 특경사기혐의 변호사 선임.txt 파일이 주휘 폴더에 복사되었습니다.
# 76_군인성추행 중간책 구속영장 처벌불원서 법적대처.txt 파일이 이사님 폴더에 복사되었습니다.
# 77_공중밀집장소추행 현행범체포 특경사기혐의 탄원서 변호사 선임.txt 파일이 팀장님 폴더에 복사되었습니다.
# 78_군인성추행 처벌불원서 무혐의 구속영장 변호사 선임.txt 파일이 주휘 폴더에 복사되었습니다.
# 79_음주운전뺑소니 경찰조사 반성문 특경사기혐의 변호사 선임.txt 파일이 이사님 폴더에 복사되었습니다.
# 7_클럽성추행 구속영장 처벌불원서 초범 변호사 선임.txt 파일이 팀장님 폴더에 복사되었습니다.
# 80_클럽성추행 탄원서 초범무혐의 경찰조사 대응방법.txt 파일이 주휘 폴더에 복사되었습니다.
# 81_카메라등이용촬영죄 현행범체포 탄원서 초범무혐의 대응방법.txt 파일이 이사님 폴더에 복사되었습니다.
# 82_지하철성추행 반성문 구속영장 중간책 변호사 선임.txt 파일이 팀장님 폴더에 복사되었습니다.
# 83_클럽성추행 현행범체포 초범무혐의 처벌불원서 대응방법.txt 파일이 주휘 폴더에 복사되었습니다.
# 84_버스성추행 구속영장 특경사기혐의 처벌불원서 변호사 선임.txt 파일이 이사님 폴더에 복사되었습니다.
# 85_보이스피싱 처벌불원서 경찰조사 무혐의 법적대처.txt 파일이 팀장님 폴더에 복사되었습니다.
# 86_군인성추행 현행범체포 중간책 탄원서 변호사 선임.txt 파일이 주휘 폴더에 복사되었습니다.
# 87_마약변호사 경찰조사 탄원서 무혐의 대응방법.txt 파일이 이사님 폴더에 복사되었습니다.
# 88_지하철성추행 처벌불원서 특경사기혐의 구속영장 대응방법.txt 파일이 팀장님 폴더에 복사되었습니다.
# 89_군인성추행 현행범체포 초범 처벌불원서 대응방법.txt 파일이 주휘 폴더에 복사되었습니다.
# 8_카메라등이용촬영죄 경찰조사 초범무혐의 탄원서 대응방법.txt 파일이 이사님 폴더에 복사되었습니다.
# 90_마약변호사 경찰조사 탄원서 초범무혐의 변호사 선임.txt 파일이 팀장님 폴더에 복사되었습니다.
# 91_보이스피싱 경찰조사 처벌불원서 초범 변호사 선임.txt 파일이 주휘 폴더에 복사되었습니다.
# 92_보이스피싱 경찰조사 탄원서 중간책 법적대처.txt 파일이 이사님 폴더에 복사되었습니다.
# 93_카메라등이용촬영죄 현행범체포 초범무혐의 반성문 변호사 선임.txt 파일이 팀장님 폴더에 복사되었습니다.
# 94_보이스피싱 경찰조사 반성문 초범무혐의 법적대처.txt 파일이 주휘 폴더에 복사되었습니다.
# 95_클럽성추행 구속영장 초범무혐의 반성문 대응방법.txt 파일이 이사님 폴더에 복사되었습니다.
# 96_음주운전뺑소니 현행범체포 반성문 무혐의 대응방법.txt 파일이 팀장님 폴더에 복사되었습니다.
# 97_군인성추행 특경사기혐의 경찰조사 반성문 법적대처.txt 파일이 주휘 폴더에 복사되었습니다.
# 98_클럽성추행 초범 처벌불원서 현행범체포 법적대처.txt 파일이 이사님 폴더에 복사되었습니다.
# 99_클럽성추행 현행범체포 처벌불원서 특경사기혐의 법적대처.txt 파일이 팀장님 폴더에 복사되었습니다.
# 9_마약변호사 반성문 구속영장 특경사기혐의 대응방법.txt 파일이 주휘 폴더에 복사되었습니다.
#
# 모든 파일 생성 및 배분이 완료되었습니다.

# %% [markdown]
# 여기서 또 돌리게 되면, 'synonym'을 이용해서 치환한 파일들이 저장됩니다.
# 아까 설정했던 base_word인 '법인회생' 폴더 안에, '오늘날짜 및 시간' 폴더 안에 전체가 저장되었습니다.

# %% [markdown]
# 결과적으로 법인회생 배분 폴더 안에 날짜/시간 폴더 안에 사람마다 배분되었습니다.
# 이제 구글드라이브에 올려 함께 이용하면 됩니다.
